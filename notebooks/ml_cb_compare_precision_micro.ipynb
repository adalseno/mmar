# %% [markdown]
# ## Compare CatBoost in the case of binary class (Sell, Buy)

# %%
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    classification_report,
    confusion_matrix,
)
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.pipeline import Pipeline

# %%
spy = pd.read_csv("../data/raw/spy.csv", parse_dates=True, index_col=0)

# %%
target = pd.read_csv("../data/processed/target_df.csv", parse_dates=True, index_col=0)[
    "target"
]

# %%
ml_df = pd.read_csv("../data/processed/ml_df.csv", parse_dates=True, index_col=0)

# %%
wk_df = pd.read_csv("../data/processed/exp_price.csv", parse_dates=True, index_col=0)

# %%
interest_rate = wk_df["r"].values

# %% [markdown]
# ### Functions

# %%
def display_report(y_test: np.ndarray, predictions: np.ndarray) -> None:
    print(classification_report(y_test, predictions))
    cm = confusion_matrix(y_test, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.show()
    return

# %%
def plot_feature_imp(coefficients: np.ndarray[float], columns: list[str]) -> None:
    feature_importance = pd.DataFrame(
        {"Feature": columns, "Importance": np.abs(coefficients)}
    )
    feature_importance = feature_importance.sort_values("Importance", ascending=True)
    feature_importance.plot(x="Feature", y="Importance", kind="barh", figsize=(10, 6))
    plt.show()
    return

# %% [markdown]
# ## Baseline CatBoost Classifier without new data + r

# %%
orig_df = ml_df[
    [
        "UNDERLYING_LAST",
        "STRIKE",
        "C_LAST",
        "C_BID",
        "C_ASK",
        "C_IV",
        "C_VOLUME",
        "diff_date",
    ]
].copy()

# %%
orig_df["r"] = interest_rate

# %% [markdown]
# ### In sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
# Adapted from https://github.com/optuna/optuna-examples/blob/main/catboost/catboost_pruning.py
def objective(trial: optuna.Trial) -> float:
    param = {
        "objective": trial.suggest_categorical(
            "objective", ["Logloss", "CrossEntropy"]
        ),
        "colsample_bylevel": trial.suggest_float(
            "colsample_bylevel", 0.01, 0.1, log=True
        ),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["Ordered", "Plain"]
        ),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 10),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    model = Pipeline(
        [
            ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
            (
                "rf",
                CatBoostClassifier(
                    **param, silent=True, early_stopping_rounds=50, random_state=1968
                ),
            ),
        ]
    )

    cv = StratifiedKFold(n_splits=4, shuffle=True, random_state=1968)

    return cross_val_score(
        model, X_train, y_train, cv=cv, scoring="precision_micro", n_jobs=1
    ).mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 08:47:26,321] A new study created in memory with name: no-name-0f70a39a-f500-4c54-9fb7-a0ca16920dd9
# [I 2024-02-12 08:47:34,923] Trial 0 finished with value: 0.5928286852589641 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.06327873406415374, 'learning_rate': 0.008291021801744238, 'depth': 6, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 98, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.5928286852589641.
# [I 2024-02-12 08:47:41,300] Trial 1 finished with value: 0.5708725099601594 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.012668445026861125, 'learning_rate': 0.05478849364225611, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 87, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.5928286852589641.
# [I 2024-02-12 08:47:47,630] Trial 2 finished with value: 0.5828525896414343 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.019452607205454896, 'learning_rate': 0.024360597135244102, 'depth': 5, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 34, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5648490925460066}. Best is trial 0 with value: 0.5928286852589641.
# [I 2024-02-12 08:47:54,832] Trial 3 finished with value: 0.5718525896414343 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.074809567139145, 'learning_rate': 0.0020458259950569156, 'depth': 3, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 38, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.5928286852589641.
# [I 2024-02-12 08:47:56,723] Trial 4 finished with value: 0.5598884462151394 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.061575758126290674, 'learning_rate': 0.0072757370653442335, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 6, 'min_data_in_leaf': 79, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.069813625822466}. Best is trial 0 with value: 0.5928286852589641.
# [I 2024-02-12 08:48:03,770] Trial 5 finished with value: 0.5568844621513944 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.058671544421318014, 'learning_rate': 0.0015474181232504236, 'depth': 4, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 83, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.5928286852589641.
# [I 2024-02-12 08:48:10,335] Trial 6 finished with value: 0.5818446215139442 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.02759094798611343, 'learning_rate': 0.032665886699947036, 'depth': 1, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 69, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.5928286852589641.
# [I 2024-02-12 08:48:17,134] Trial 7 finished with value: 0.5748565737051793 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09057966366212723, 'learning_rate': 0.03952593552476787, 'depth': 2, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 79, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.305177330925419}. Best is trial 0 with value: 0.5928286852589641.
# [I 2024-02-12 08:48:19,228] Trial 8 finished with value: 0.6257450199203187 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0725802793834302, 'learning_rate': 0.027365334132112715, 'depth': 3, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 50, 'bootstrap_type': 'MVS'}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:21,233] Trial 9 finished with value: 0.5359402390438247 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.033609711563926045, 'learning_rate': 0.0013972171640818647, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 98, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.7873374201901595}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:22,890] Trial 10 finished with value: 0.6038207171314741 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.03944148891773124, 'learning_rate': 0.09979955808093853, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 11, 'bootstrap_type': 'Bernoulli', 'subsample': 0.10951604782765344}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:24,560] Trial 11 finished with value: 0.5888486055776893 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.044976485071881914, 'learning_rate': 0.07234666575335652, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 1, 'bootstrap_type': 'Bernoulli', 'subsample': 0.10681617005460463}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:26,326] Trial 12 finished with value: 0.5668764940239044 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.04040014581941243, 'learning_rate': 0.016103192680050074, 'depth': 11, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 1, 'bootstrap_type': 'Bernoulli', 'subsample': 0.11044414540992038}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:28,087] Trial 13 finished with value: 0.5908486055776893 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.021322305697563368, 'learning_rate': 0.09253083052666952, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 25, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2719925093390234}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:30,579] Trial 14 finished with value: 0.5798525896414343 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09774522411863858, 'learning_rate': 0.004277796852906089, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 51, 'bootstrap_type': 'Bernoulli', 'subsample': 0.27350007546380123}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:32,366] Trial 15 finished with value: 0.5928167330677291 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.03983282974842803, 'learning_rate': 0.017494579139833842, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 16, 'bootstrap_type': 'MVS'}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:34,027] Trial 16 finished with value: 0.603792828685259 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.04902024716922674, 'learning_rate': 0.04743238415079316, 'depth': 4, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 56, 'bootstrap_type': 'Bernoulli', 'subsample': 0.1730373410830075}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:35,740] Trial 17 finished with value: 0.6247609561752988 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.027800492868251772, 'learning_rate': 0.09893643501740094, 'depth': 7, 'boosting_type': 'Plain', 'l2_leaf_reg': 10, 'min_data_in_leaf': 16, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8219691630664642}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:37,354] Trial 18 finished with value: 0.5638924302788845 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.010721605121764071, 'learning_rate': 0.015054162166881158, 'depth': 7, 'boosting_type': 'Plain', 'l2_leaf_reg': 10, 'min_data_in_leaf': 62, 'bootstrap_type': 'MVS'}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:39,032] Trial 19 finished with value: 0.5498884462151394 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.02571307615635974, 'learning_rate': 0.028849155310027137, 'depth': 2, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 29, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.125482923846432}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:40,734] Trial 20 finished with value: 0.5319442231075697 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.017048994052827837, 'learning_rate': 0.0030079531459424455, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 8, 'min_data_in_leaf': 43, 'bootstrap_type': 'MVS'}. Best is trial 8 with value: 0.6257450199203187.
# [I 2024-02-12 08:48:42,325] Trial 21 finished with value: 0.6347410358565737 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.03113557584210816, 'learning_rate': 0.09239890453414226, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 16, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9826734977960402}. Best is trial 21 with value: 0.6347410358565737.
# [I 2024-02-12 08:48:44,050] Trial 22 finished with value: 0.6137649402390438 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0313362147773722, 'learning_rate': 0.05934310738263595, 'depth': 7, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 20, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9838335085711467}. Best is trial 21 with value: 0.6347410358565737.
# [I 2024-02-12 08:48:45,662] Trial 23 finished with value: 0.607792828685259 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.02377988918111603, 'learning_rate': 0.07888164397310368, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 11, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9427195737492382}. Best is trial 21 with value: 0.6347410358565737.
# [I 2024-02-12 08:48:47,294] Trial 24 finished with value: 0.603808764940239 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.030644170710888756, 'learning_rate': 0.0431891611122122, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 6, 'min_data_in_leaf': 41, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6103152634003698}. Best is trial 21 with value: 0.6347410358565737.
# [I 2024-02-12 08:48
 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 53, 'bootstrap_type': 'MVS'}. Best is trial 47 with value: 0.6896334661354582.
# [I 2024-02-12 08:56:47,394] Trial 96 finished with value: 0.5918565737051793 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08461308466148071, 'learning_rate': 0.005892964301194021, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 71, 'bootstrap_type': 'MVS'}. Best is trial 47 with value: 0.6896334661354582.
# [I 2024-02-12 08:56:54,803] Trial 97 finished with value: 0.5758486055776892 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0778800009710899, 'learning_rate': 0.0024291314048888106, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 63, 'bootstrap_type': 'MVS'}. Best is trial 47 with value: 0.6896334661354582.
# [I 2024-02-12 08:57:01,904] Trial 98 finished with value: 0.6557051792828685 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0673544766885764, 'learning_rate': 0.0608156047974242, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 68, 'bootstrap_type': 'MVS'}. Best is trial 47 with value: 0.6896334661354582.
# [I 2024-02-12 08:57:08,869] Trial 99 finished with value: 0.6487211155378486 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06396172148269884, 'learning_rate': 0.056587834855477186, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 57, 'bootstrap_type': 'MVS'}. Best is trial 47 with value: 0.6896334661354582.
# [I 2024-02-12 08:57:16,896] Trial 100 finished with value: 0.6736573705179283 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09293110053446665, 'learning_rate': 0.07619167999673855, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 48, 'bootstrap_type': 'MVS'}. Best is trial 47 with value: 0.6896334661354582.
# [I 2024-02-12 08:57:24,832] Trial 101 finished with value: 0.6696573705179283 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0930452250266206, 'learning_rate': 0.07603782528480726, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 48, 'bootstrap_type': 'MVS'}. Best is trial 47 with value: 0.6896334661354582.
# [I 2024-02-12 08:57:32,914] Trial 102 finished with value: 0.6826653386454182 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09275546787356369, 'learning_rate': 0.09061486847449467, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 46, 'bootstrap_type': 'MVS'}. Best is trial 47 with value: 0.6896334661354582.
# Number of finished trials: 103
# Best trial:
#   Value: 0.6896334661354582
#   Params:
#     objective: Logloss
#     colsample_bylevel: 0.09436451318127773
#     learning_rate: 0.07307180837448587
#     depth: 9
#     boosting_type: Ordered
#     l2_leaf_reg: 8
#     min_data_in_leaf: 77
#     bootstrap_type: MVS

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09436451318127773, 'learning_rate': 0.07307180837448587, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 77, 'bootstrap_type': 'MVS'}
# Best score: 0.6896334661354582

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x1350deb10>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6892430278884463

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69       123
#            1       0.70      0.67      0.69       128
#
#     accuracy                           0.69       251
#    macro avg       0.69      0.69      0.69       251
# weighted avg       0.69      0.69      0.69       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df = pd.DataFrame(predictions, columns=["bare_rf_pred_in"])

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price     profit  \
# Date
# 2018-02-05         0   265.0        8.22  2018-02-28   271.649994   0.000000
# 2018-02-22         0   270.0        4.26  2018-03-14   275.299988   0.000000
# 2018-03-08         1   274.0        2.85  2018-03-29   263.149994  -2.850000
# 2018-03-09         0   279.0        2.47  2018-03-29   263.149994   0.000000
# 2018-04-03         1   260.5        5.09  2018-04-23   266.570007   0.980007
# ...              ...     ...         ...         ...          ...        ...
# 2022-10-25         0   385.0       10.50  2022-11-14   395.119995   0.000000
# 2022-11-01         0   385.0        9.48  2022-11-21   394.589996   0.000000
# 2022-11-02         1   375.0       10.19  2022-11-23   402.420013  17.230013
# 2022-12-01         0   407.0        7.97  2022-12-23   382.910004   0.000000
# 2022-12-19         0   380.0        7.22  2023-01-06   388.079987   0.000000
#
#                  bare  cum_profit    cum_bare
# Date
# 2018-02-05  -1.570006    0.000000   -1.570006
# 2018-02-22   1.039988    0.000000   -0.530018
# 2018-03-08  -2.850000   -2.850000   -3.380018
# 2018-03-09  -2.470000   -2.850000   -5.850018
# 2018-04-03   0.980007   -1.869993   -4.870011
# ...               ...         ...         ...
# 2022-10-25  -0.380005  386.189880  389.189830
# 2022-11-01   0.109996  386.189880  389.299827
# 2022-11-02  17.230013  403.419894  406.529840
# 2022-12-01  -7.970000  403.419894  398.559840
# 2022-12-19   0.859987  403.419894  399.419827
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only in sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x13534e650>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6135458167330677

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.74       177
#            1       0.27      0.18      0.21        74
#
#     accuracy                           0.61       251
#    macro avg       0.48      0.49      0.48       251
# weighted avg       0.57      0.61      0.59       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["bare_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = orig_df.iloc[-i, :].to_dict()
    quote_date = orig_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price  profit  \
# Date
# 2022-01-03         0   478.0        4.81  2022-01-24   439.839996     0.0
# 2022-01-04         0   478.0        4.80  2022-01-24   439.839996     0.0
# 2022-01-05         0   468.0        8.14  2022-01-26   433.380005     0.0
# 2022-01-06         0   468.0        7.00  2022-01-26   433.380005     0.0
# 2022-01-07         0   466.0        7.56  2022-01-28   441.950012     0.0
# ...              ...     ...         ...         ...          ...     ...
# 2022-12-23         0   383.0        8.00  2023-01-13   398.500000     0.0
# 2022-12-26         0   383.0        7.96  2023-01-13   398.500000     0.0
# 2022-12-28         0   377.0        8.75  2023-01-20   395.880005     0.0
# 2022-12-29         0   383.0        8.50  2023-01-20   395.880005     0.0
# 2022-12-30         0   382.0        8.21  2023-01-20   395.880005     0.0
#
#                  bare  cum_profit    cum_bare
# Date
# 2022-01-03  -4.810000    0.000000   -4.810000
# 2022-01-04  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000    0.000000  -17.750000
# 2022-01-06  -7.000000    0.000000  -24.750000
# 2022-01-07  -7.560000    0.000000  -32.310000
# ...               ...         ...         ...
# 2022-12-23   7.500000 -165.180002 -525.980022
# 2022-12-26   7.540000 -165.180002 -518.440022
# 2022-12-28  10.130005 -165.180002 -508.310017
# 2022-12-29   4.380005 -165.180002 -503.930012
# 2022-12-30   5.670005 -165.180002 -498.260007
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## CatBoost with data from MC simulation and additional features

# %%
new_df = pd.concat(
    (
        ml_df[
            [
                "UNDERLYING_LAST",
                "STRIKE",
                "C_LAST",
                "C_BID",
                "C_ASK",
                "C_IV",
                "C_VOLUME",
                "diff",
            ]
        ],
        wk_df.drop(["last_quote", "strike"], axis=1),
    ),
    axis=1,
)

# %%
# Add some features
new_df["iqr"] = new_df["exp_price_q3"] - new_df["exp_price_q1"]
new_df["diff_call"] = new_df["exp_call_price"] - new_df["C_LAST"]
new_df["exp_price_var"] = np.power(new_df["exp_price_std"], 2)
new_df["exp_profit"] = new_df["exp_price"] - (new_df["STRIKE"] + new_df["C_LAST"])

# %% [markdown]
# ### In-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, timeout=1200)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 08:57:41,800] A new study created in memory with name: no-name-f6d3002d-c640-429c-a673-2922d94fb396
# [I 2024-02-12 08:57:44,306] Trial 0 finished with value: 0.5568844621513944 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0186672654231469, 'learning_rate': 0.0010501148015508448, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 30, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.5568844621513944.
# [I 2024-02-12 08:57:46,063] Trial 1 finished with value: 0.6656892430278885 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.021005121373507053, 'learning_rate': 0.051161307265725396, 'depth': 11, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 50, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4473781412009221}. Best is trial 1 with value: 0.6656892430278885.
# [I 2024-02-12 08:57:53,030] Trial 2 finished with value: 0.5439243027888446 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.018975069561503917, 'learning_rate': 0.0011301045791662757, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 3, 'min_data_in_leaf': 49, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.17119372694888}. Best is trial 1 with value: 0.6656892430278885.
# [I 2024-02-12 08:58:00,341] Trial 3 finished with value: 0.6856414342629482 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08036636674211568, 'learning_rate': 0.0362051177329398, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 13, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.088010618912989}. Best is trial 3 with value: 0.6856414342629482.
# [I 2024-02-12 08:58:02,210] Trial 4 finished with value: 0.5668764940239044 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.01985780174975899, 'learning_rate': 0.006829140409329243, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 53, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.047266727321897}. Best is trial 3 with value: 0.6856414342629482.
# [I 2024-02-12 08:58:04,327] Trial 5 finished with value: 0.6816613545816733 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.02389628066050877, 'learning_rate': 0.043574902531756506, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 10, 'min_data_in_leaf': 83, 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.6856414342629482.
# [I 2024-02-12 08:58:05,942] Trial 6 finished with value: 0.5978326693227092 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.010705477365470846, 'learning_rate': 0.029222633430028455, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 54, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5469506820634513}. Best is trial 3 with value: 0.6856414342629482.
# [I 2024-02-12 08:58:08,027] Trial 7 finished with value: 0.5958127490039841 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.02533951779240519, 'learning_rate': 0.012787137236141903, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 10, 'min_data_in_leaf': 66, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.552434865956865}. Best is trial 3 with value: 0.6856414342629482.
# [I 2024-02-12 08:58:09,979] Trial 8 finished with value: 0.6936254980079681 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.019811070798210192, 'learning_rate': 0.054377961264911456, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 97, 'bootstrap_type': 'MVS'}. Best is trial 8 with value: 0.6936254980079681.
# [I 2024-02-12 08:58:11,775] Trial 9 finished with value: 0.600808764940239 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.013402068855231816, 'learning_rate': 0.06073761666359208, 'depth': 4, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 50, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.032423403136083}. Best is trial 8 with value: 0.6936254980079681.
# [I 2024-02-12 08:58:18,920] Trial 10 finished with value: 0.5588804780876494 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04472300755057038, 'learning_rate': 0.005388807309165522, 'depth': 1, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 94, 'bootstrap_type': 'MVS'}. Best is trial 8 with value: 0.6936254980079681.
# [I 2024-02-12 08:58:47,566] Trial 11 finished with value: 0.7544741035856573 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09442410503877038, 'learning_rate': 0.09784864628344614, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 2, 'bootstrap_type': 'MVS'}. Best is trial 11 with value: 0.7544741035856573.
# [I 2024-02-12 08:58:58,618] Trial 12 finished with value: 0.7474900398406374 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.047685119694551185, 'learning_rate': 0.08499358599311325, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 4, 'bootstrap_type': 'MVS'}. Best is trial 11 with value: 0.7544741035856573.
# [I 2024-02-12 08:59:41,397] Trial 13 finished with value: 0.7714581673306773 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0921668104441478, 'learning_rate': 0.09964009399385362, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 1, 'bootstrap_type': 'MVS'}. Best is trial 13 with value: 0.7714581673306773.
# [I 2024-02-12 08:59:55,520] Trial 14 finished with value: 0.7365338645418327 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.
and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.061406916707102195, 'learning_rate': 0.08459135676817513, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 92, 'bootstrap_type': 'MVS'}. Best is trial 13 with value: 0.7714581673306773.
# [I 2024-02-12 09:13:07,865] Trial 60 finished with value: 0.7525099601593626 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05076921502343436, 'learning_rate': 0.044195361677916864, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 10, 'min_data_in_leaf': 76, 'bootstrap_type': 'MVS'}. Best is trial 13 with value: 0.7714581673306773.
# [I 2024-02-12 09:13:29,200] Trial 61 finished with value: 0.7654741035856574 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06814780695782781, 'learning_rate': 0.05321752891671451, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 100, 'bootstrap_type': 'MVS'}. Best is trial 13 with value: 0.7714581673306773.
# [I 2024-02-12 09:13:51,283] Trial 62 finished with value: 0.7734701195219125 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06986616258426509, 'learning_rate': 0.09789274885822595, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 98, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:14:15,251] Trial 63 finished with value: 0.7544900398406373 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07179899929220958, 'learning_rate': 0.09943535992304367, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 85, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:14:21,783] Trial 64 finished with value: 0.7015856573705179 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.02220460810597864, 'learning_rate': 0.07877390218711876, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 89, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:14:38,753] Trial 65 finished with value: 0.7574820717131474 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05480001294832778, 'learning_rate': 0.06495094748235494, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 96, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:16:09,628] Trial 66 finished with value: 0.7425378486055778 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07574683509187474, 'learning_rate': 0.08919603665454032, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 94, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3986755955795794}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:16:25,608] Trial 67 finished with value: 0.7664860557768924 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.060393177703169924, 'learning_rate': 0.07055482455501016, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 57, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:16:42,823] Trial 68 finished with value: 0.6946175298804782 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06301185332605692, 'learning_rate': 0.00553082294424707, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 100, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:16:57,214] Trial 69 finished with value: 0.6846454183266933 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05673489208678435, 'learning_rate': 0.07440710360988358, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 47, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.591570243864666}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:17:08,525] Trial 70 finished with value: 0.7524661354581672 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04701688749993575, 'learning_rate': 0.08601455433588492, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 56, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:17:30,122] Trial 71 finished with value: 0.7594701195219122 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0681267913140225, 'learning_rate': 0.05914883680337611, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 70, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# [I 2024-02-12 09:18:18,350] Trial 72 finished with value: 0.7544780876494024 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08151432319299562, 'learning_rate': 0.09959402704409429, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 37, 'bootstrap_type': 'MVS'}. Best is trial 62 with value: 0.7734701195219125.
# Number of finished trials: 73
# Best trial:
#   Value: 0.7734701195219125
#   Params:
#     objective: Logloss
#     colsample_bylevel: 0.06986616258426509
#     learning_rate: 0.09789274885822595
#     depth: 10
#     boosting_type: Ordered
#     l2_leaf_reg: 9
#     min_data_in_leaf: 98
#     bootstrap_type: MVS

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06986616258426509, 'learning_rate': 0.09789274885822595, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 98, 'bootstrap_type': 'MVS'}
# Best score: 0.7734701195219125

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x135320d50>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.7450199203187251

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.74       123
#            1       0.76      0.73      0.75       128
#
#     accuracy                           0.75       251
#    macro avg       0.75      0.75      0.75       251
# weighted avg       0.75      0.75      0.75       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_in"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price  exp_call    exp_date  final_price  \
# Date
# 2018-02-05         1   265.0        8.22  4.942161  2018-02-28   271.649994
# 2018-02-22         0   270.0        4.26  6.397086  2018-03-14   275.299988
# 2018-03-08         0   274.0        2.85  5.917690  2018-03-29   263.149994
# 2018-03-09         0   279.0        2.47  5.505012  2018-03-29   263.149994
# 2018-04-03         1   260.5        5.09  5.247430  2018-04-23   266.570007
# ...              ...     ...         ...       ...         ...          ...
# 2022-10-25         0   385.0       10.50  9.062317  2022-11-14   395.119995
# 2022-11-01         1   385.0        9.48  8.719475  2022-11-21   394.589996
# 2022-11-02         1   375.0       10.19  8.901524  2022-11-23   402.420013
# 2022-12-01         0   407.0        7.97  9.399281  2022-12-23   382.910004
# 2022-12-19         0   380.0        7.22  7.839602  2023-01-06   388.079987
#
#                profit       bare  cum_profit    cum_bare
# Date
# 2018-02-05  -1.570006  -1.570006   -1.570006   -1.570006
# 2018-02-22   0.000000   1.039988   -1.570006   -0.530018
# 2018-03-08   0.000000  -2.850000   -1.570006   -3.380018
# 2018-03-09   0.000000  -2.470000   -1.570006   -5.850018
# 2018-04-03   0.980007   0.980007   -0.589999   -4.870011
# ...               ...        ...         ...         ...
# 2022-10-25   0.000000  -0.380005  498.469862  389.189830
# 2022-11-01   0.109996   0.109996  498.579858  389.299827
# 2022-11-02  17.230013  17.230013  515.809872  406.529840
# 2022-12-01   0.000000  -7.970000  515.809872  398.559840
# 2022-12-19   0.000000   0.859987  515.809872  399.419827
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions +data (Buy only in-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x135065650>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.4581673306772908

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.31      0.44       177
#            1       0.33      0.82      0.47        74
#
#     accuracy                           0.46       251
#    macro avg       0.57      0.56      0.46       251
# weighted avg       0.67      0.46      0.45       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = new_df.iloc[-i, :].to_dict()
    quote_date = new_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price   exp_call    exp_date  final_price  \
# Date
# 2022-01-03         0   478.0        4.81  10.248337  2022-01-24   439.839996
# 2022-01-04         0   478.0        4.80   9.610177  2022-01-24   439.839996
# 2022-01-05         1   468.0        8.14  10.191128  2022-01-26   433.380005
# 2022-01-06         1   468.0        7.00   9.657596  2022-01-26   433.380005
# 2022-01-07         1   466.0        7.56   9.927762  2022-01-28   441.950012
# ...              ...     ...         ...        ...         ...          ...
# 2022-12-23         1   383.0        8.00   8.453400  2023-01-13   398.500000
# 2022-12-26         1   383.0        7.96   8.096501  2023-01-13   398.500000
# 2022-12-28         1   377.0        8.75   8.526141  2023-01-20   395.880005
# 2022-12-29         1   383.0        8.50   8.908718  2023-01-20   395.880005
# 2022-12-30         1   382.0        8.21   8.652675  2023-01-20   395.880005
#
#                profit       bare  cum_profit    cum_bare
# Date
# 2022-01-03   0.000000  -4.810000    0.000000   -4.810000
# 2022-01-04   0.000000  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000  -8.140000   -8.140000  -17.750000
# 2022-01-06  -7.000000  -7.000000  -15.140000  -24.750000
# 2022-01-07  -7.560000  -7.560000  -22.700000  -32.310000
# ...               ...        ...         ...         ...
# 2022-12-23   7.500000   7.500000 -332.949962 -525.980022
# 2022-12-26   7.540000   7.540000 -325.409962 -518.440022
# 2022-12-28  10.130005  10.130005 -315.279957 -508.310017
# 2022-12-29   4.380005   4.380005 -310.899952 -503.930012
# 2022-12-30   5.670005   5.670005 -305.229948 -498.260007
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions + data (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## Compare the two predictions

# %%
mask_in = (compare_df["bare_rf_pred_in"] - compare_df["mmar_rf_pred_in"]).astype(bool)
mask_out = (compare_df["bare_rf_pred_out"] - compare_df["mmar_rf_pred_out"]).astype(
    bool
)

# %%
compare_df[mask_in]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 2                  1                 0                0                 1
# 3                  1                 0                0                 1
# 23                 0                 1                1                 1
# 28                 1                 1                0                 0
# 35                 1                 1                0                 1
# 39                 0                 1                1                 1
# 46                 1                 0                0                 1
# 47                 0                 1                1                 1
# 50                 0                 0                1                 1
# 51                 1                 0                0                 1
# 55                 0                 0                1                 0
# 77                 0                 0                1                 1
# 87                 1                 0                0                 1
# 99                 0                 1                1                 1
# 103                0                 0                1                 1
# 110                1                 0                0                 1
# 120                0                 0                1                 1
# 122                0                 0                1                 1
# 131                0                 0                1                 1
# 136                1                 0                0                 1
# 137                1                 0                0                 0
# 141                0                 0                1                 0
# 146                0                 0                1                 0
# 147                0                 0                1                 1
# 151                0                 0                1                 0
# 156                1                 0                0                 0
# 158                1                 0                0                 0
# 160                1                 0                0                 0
# 164                1                 0                0                 0
# 167                0                 0                1                 0
# 169                1                 0                0                 0
# 170                1                 0                0                 0
# 171                0                 0                1                 0
# 173                0                 0                1                 1
# 174                0                 0                1                 0
# 184                1                 0                0                 1
# 186                0                 0                1                 1
# 188                0                 0                1                 1
# 191                0                 0                1                 1
# 193                0                 0                1                 1
# 194                1                 0                0                 1
# 195                1                 0                0                 1
# 203                0                 0                1                 1
# 209                1                 0                0                 1
# 210                0                 0                1                 1
# 212                1                 0                0                 1
# 225                1                 0                0                 1
# 232                1                 0                0                 1
# 237                1                 0                0                 1
# 246                0                 0                1                 1

# %%
compare_df[mask_in].shape
# Out:
# (50, 4)

# %%
# Compare out of sample preds
compare_df[mask_out]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 2                  1                 0                0                 1
# 3                  1                 0                0                 1
# 4                  1                 0                1                 1
# 5                  0                 0                0                 1
# 6                  0                 0                0                 1
# ..               ...               ...              ...               ...
# 246                0                 0                1                 1
# 247                1                 0                1                 1
# 248                1                 0                1                 1
# 249                0                 0                0                 1
# 250                1                 0                1                 1
#
# [155 rows x 4 columns]

# %%
compare_df[mask_out].shape
# Out:
# (155, 4)

# %%
compare_df.sum(axis=0)
# Out:
# bare_rf_pred_in     122
# bare_rf_pred_out     49
# mmar_rf_pred_in     124
# mmar_rf_pred_out    184
# dtype: int64
