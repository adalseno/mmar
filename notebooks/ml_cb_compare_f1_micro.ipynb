# %% [markdown]
# ## Compare CatBoost in the case of binary class (Sell, Buy)

# %%
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    classification_report,
    confusion_matrix,
)
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.pipeline import Pipeline

# %%
spy = pd.read_csv("../data/raw/spy.csv", parse_dates=True, index_col=0)

# %%
target = pd.read_csv("../data/processed/target_df.csv", parse_dates=True, index_col=0)[
    "target"
]

# %%
ml_df = pd.read_csv("../data/processed/ml_df.csv", parse_dates=True, index_col=0)

# %%
wk_df = pd.read_csv("../data/processed/exp_price.csv", parse_dates=True, index_col=0)

# %%
interest_rate = wk_df["r"].values

# %% [markdown]
# ### Functions

# %%
def display_report(y_test: np.ndarray, predictions: np.ndarray) -> None:
    print(classification_report(y_test, predictions))
    cm = confusion_matrix(y_test, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.show()
    return

# %%
def plot_feature_imp(coefficients: np.ndarray[float], columns: list[str]) -> None:
    feature_importance = pd.DataFrame(
        {"Feature": columns, "Importance": np.abs(coefficients)}
    )
    feature_importance = feature_importance.sort_values("Importance", ascending=True)
    feature_importance.plot(x="Feature", y="Importance", kind="barh", figsize=(10, 6))
    plt.show()
    return

# %% [markdown]
# ## Baseline CatBoost Classifier without new data + r

# %%
orig_df = ml_df[
    [
        "UNDERLYING_LAST",
        "STRIKE",
        "C_LAST",
        "C_BID",
        "C_ASK",
        "C_IV",
        "C_VOLUME",
        "diff_date",
    ]
].copy()

# %%
orig_df["r"] = interest_rate

# %% [markdown]
# ### In sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
# Adapted from https://github.com/optuna/optuna-examples/blob/main/catboost/catboost_pruning.py
def objective(trial: optuna.Trial) -> float:
    param = {
        "objective": trial.suggest_categorical(
            "objective", ["Logloss", "CrossEntropy"]
        ),
        "colsample_bylevel": trial.suggest_float(
            "colsample_bylevel", 0.01, 0.1, log=True
        ),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["Ordered", "Plain"]
        ),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 10),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    model = Pipeline(
        [
            ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
            (
                "rf",
                CatBoostClassifier(
                    **param, silent=True, early_stopping_rounds=50, random_state=1968
                ),
            ),
        ]
    )

    cv = StratifiedKFold(n_splits=4, shuffle=True, random_state=1968)

    return cross_val_score(
        model, X_train, y_train, cv=cv, scoring="f1_micro", n_jobs=1
    ).mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 11:03:46,002] A new study created in memory with name: no-name-892078ca-2eca-4f80-8a9d-f253dd934690
# [I 2024-02-12 11:03:49,309] Trial 0 finished with value: 0.605796812749004 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07918898377916468, 'learning_rate': 0.0169370872308179, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 8, 'min_data_in_leaf': 47, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4153702633189648}. Best is trial 0 with value: 0.605796812749004.
# [I 2024-02-12 11:03:50,963] Trial 1 finished with value: 0.5808605577689243 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05164812855450107, 'learning_rate': 0.017701069304290207, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 7, 'min_data_in_leaf': 26, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2629080501895857}. Best is trial 0 with value: 0.605796812749004.
# [I 2024-02-12 11:03:57,405] Trial 2 finished with value: 0.5518884462151394 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.02248416031460937, 'learning_rate': 0.02640552784509987, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 30, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.7023371362489}. Best is trial 0 with value: 0.605796812749004.
# [I 2024-02-12 11:03:59,242] Trial 3 finished with value: 0.5578844621513944 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04378381420191507, 'learning_rate': 0.003056133375064718, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 8, 'min_data_in_leaf': 23, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.605796812749004.
# [I 2024-02-12 11:04:05,882] Trial 4 finished with value: 0.5768605577689243 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0
. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:36,266] Trial 141 finished with value: 0.704605577689243 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09428639822918523, 'learning_rate': 0.0817110439274354, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 6, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8901499936619525}. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:38,362] Trial 142 finished with value: 0.6836414342629482 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09575705747107777, 'learning_rate': 0.08157710644546898, 'depth': 7, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 7, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9200885044066006}. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:40,329] Trial 143 finished with value: 0.697609561752988 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08993690303339422, 'learning_rate': 0.07472737587183603, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 3, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9959620917789307}. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:42,585] Trial 144 finished with value: 0.706597609561753 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09988309294727563, 'learning_rate': 0.08499180143783404, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 8, 'bootstrap_type': 'Bernoulli', 'subsample': 0.846316245211428}. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:44,491] Trial 145 finished with value: 0.6836613545816732 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09249920534515502, 'learning_rate': 0.059458230285783786, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 9, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8505719239748977}. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:46,549] Trial 146 finished with value: 0.7056095617529882 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0868805810525819, 'learning_rate': 0.06865095547017204, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 8, 'bootstrap_type': 'MVS'}. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:48,549] Trial 147 finished with value: 0.6926374501992032 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08658768526079057, 'learning_rate': 0.05317392740815976, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 12, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7543845150320675}. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:50,663] Trial 148 finished with value: 0.6985976095617531 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08867140489734822, 'learning_rate': 0.0992565657571027, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 14, 'bootstrap_type': 'MVS'}. Best is trial 74 with value: 0.7195617529880478.
# [I 2024-02-12 11:09:52,597] Trial 149 finished with value: 0.7106135458167331 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07697300924870981, 'learning_rate': 0.07164586295442124, 'depth': 11, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 62, 'bootstrap_type': 'MVS'}. Best is trial 74 with value: 0.7195617529880478.
# Number of finished trials: 150
# Best trial:
#   Value: 0.7195617529880478
#   Params:
#     objective: Logloss
#     colsample_bylevel: 0.095793959662092
#     learning_rate: 0.07085071644436128
#     depth: 6
#     boosting_type: Plain
#     l2_leaf_reg: 3
#     min_data_in_leaf: 15
#     bootstrap_type: Bernoulli
#     subsample: 0.741256776009988

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'Logloss', 'colsample_bylevel': 0.095793959662092, 'learning_rate': 0.07085071644436128, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 15, 'bootstrap_type': 'Bernoulli', 'subsample': 0.741256776009988}
# Best score: 0.7195617529880478

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x12a1f1450>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6852589641434262

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.73      0.69       123
#            1       0.71      0.64      0.67       128
#
#     accuracy                           0.69       251
#    macro avg       0.69      0.69      0.68       251
# weighted avg       0.69      0.69      0.68       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df = pd.DataFrame(predictions, columns=["bare_rf_pred_in"])

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price     profit  \
# Date
# 2018-02-05         1   265.0        8.22  2018-02-28   271.649994  -1.570006
# 2018-02-22         0   270.0        4.26  2018-03-14   275.299988   0.000000
# 2018-03-08         0   274.0        2.85  2018-03-29   263.149994   0.000000
# 2018-03-09         0   279.0        2.47  2018-03-29   263.149994   0.000000
# 2018-04-03         1   260.5        5.09  2018-04-23   266.570007   0.980007
# ...              ...     ...         ...         ...          ...        ...
# 2022-10-25         0   385.0       10.50  2022-11-14   395.119995   0.000000
# 2022-11-01         0   385.0        9.48  2022-11-21   394.589996   0.000000
# 2022-11-02         1   375.0       10.19  2022-11-23   402.420013  17.230013
# 2022-12-01         0   407.0        7.97  2022-12-23   382.910004   0.000000
# 2022-12-19         0   380.0        7.22  2023-01-06   388.079987   0.000000
#
#                  bare  cum_profit    cum_bare
# Date
# 2018-02-05  -1.570006   -1.570006   -1.570006
# 2018-02-22   1.039988   -1.570006   -0.530018
# 2018-03-08  -2.850000   -1.570006   -3.380018
# 2018-03-09  -2.470000   -1.570006   -5.850018
# 2018-04-03   0.980007   -0.589999   -4.870011
# ...               ...         ...         ...
# 2022-10-25  -0.380005  383.059845  389.189830
# 2022-11-01   0.109996  383.059845  389.299827
# 2022-11-02  17.230013  400.289858  406.529840
# 2022-12-01  -7.970000  400.289858  398.559840
# 2022-12-19   0.859987  400.289858  399.419827
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only in sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x12a4b7f90>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6135458167330677

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.75       177
#            1       0.19      0.09      0.13        74
#
#     accuracy                           0.61       251
#    macro avg       0.44      0.46      0.44       251
# weighted avg       0.54      0.61      0.57       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["bare_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = orig_df.iloc[-i, :].to_dict()
    quote_date = orig_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price  profit  \
# Date
# 2022-01-03         0   478.0        4.81  2022-01-24   439.839996     0.0
# 2022-01-04         0   478.0        4.80  2022-01-24   439.839996     0.0
# 2022-01-05         0   468.0        8.14  2022-01-26   433.380005     0.0
# 2022-01-06         0   468.0        7.00  2022-01-26   433.380005     0.0
# 2022-01-07         0   466.0        7.56  2022-01-28   441.950012     0.0
# ...              ...     ...         ...         ...          ...     ...
# 2022-12-23         0   383.0        8.00  2023-01-13   398.500000     0.0
# 2022-12-26         0   383.0        7.96  2023-01-13   398.500000     0.0
# 2022-12-28         0   377.0        8.75  2023-01-20   395.880005     0.0
# 2022-12-29         0   383.0        8.50  2023-01-20   395.880005     0.0
# 2022-12-30         0   382.0        8.21  2023-01-20   395.880005     0.0
#
#                  bare  cum_profit    cum_bare
# Date
# 2022-01-03  -4.810000    0.000000   -4.810000
# 2022-01-04  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000    0.000000  -17.750000
# 2022-01-06  -7.000000    0.000000  -24.750000
# 2022-01-07  -7.560000    0.000000  -32.310000
# ...               ...         ...         ...
# 2022-12-23   7.500000 -211.260017 -525.980022
# 2022-12-26   7.540000 -211.260017 -518.440022
# 2022-12-28  10.130005 -211.260017 -508.310017
# 2022-12-29   4.380005 -211.260017 -503.930012
# 2022-12-30   5.670005 -211.260017 -498.260007
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## CatBoost with data from MC simulation and additional features

# %%
new_df = pd.concat(
    (
        ml_df[
            [
                "UNDERLYING_LAST",
                "STRIKE",
                "C_LAST",
                "C_BID",
                "C_ASK",
                "C_IV",
                "C_VOLUME",
                "diff",
            ]
        ],
        wk_df.drop(["last_quote", "strike"], axis=1),
    ),
    axis=1,
)

# %%
# Add some features
new_df["iqr"] = new_df["exp_price_q3"] - new_df["exp_price_q1"]
new_df["diff_call"] = new_df["exp_call_price"] - new_df["C_LAST"]
new_df["exp_price_var"] = np.power(new_df["exp_price_std"], 2)
new_df["exp_profit"] = new_df["exp_price"] - (new_df["STRIKE"] + new_df["C_LAST"])

# %% [markdown]
# ### In-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, timeout=1200)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 11:09:58,494] A new study created in memory with name: no-name-14e6298c-82f5-464b-8909-5e99049010b4
# [I 2024-02-12 11:10:06,417] Trial 0 finished with value: 0.5718685258964143 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.016650639363537237, 'learning_rate': 0.014750848854836013, 'depth': 7, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 28, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2171723238507582}. Best is trial 0 with value: 0.5718685258964143.
# [I 2024-02-12 11:10:11,321] Trial 1 finished with value: 0.6576892430278884 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06784337633113832, 'learning_rate': 0.0012253417726975962, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 6, 'min_data_in_leaf': 43, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6704696574459522}. Best is trial 1 with value: 0.6576892430278884.
# [I 2024-02-12 11:10:19,636] Trial 2 finished with value: 0.7185657370517928 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.04077194943083375, 'learning_rate': 0.030088856050548538, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 1, 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.7185657370517928.
# [I 2024-02-12 11:10:24,732] Trial 3 finished with value: 0.7485059760956174 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05840845754879006, 'learning_rate': 0.03619090827805134, 'depth': 11, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 36, 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.7485059760956174.
# [I 2024-02-12 11:10:26,797] Trial 4 finished with value: 0.6008366533864542 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03300791761281366, 'learning_rate': 0.0053299735200902955, 'depth': 3, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 64, 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.7485059760956174.
# [I 2024-02-12 11:10:33,926] Trial 5 finished with value: 0.6816613545816734 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.023407868085832444, 'learning_rate': 0.04322702629203426, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 42, 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.7485059760956174.
# [I 2024-02-12 11:10:40,131] Trial 6 finished with value: 0.5579083665338646 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.014612084464102745, 'learning_rate': 0.031822472349622634, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 4, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.7273876747225145}. Best is trial 3 with value: 0.7485059760956174.
# [I 2024-02-12 11:10:41,992] Trial 7 finished with value: 0.5618605577689243 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.02082451848234664, 'learning_rate': 0.0020375091834868887, 'depth': 2, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 77, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9505328063023284}. Best is trial 3 with value: 0.7485059760956174.
# [I 2024-02-12 11:10:48,334] Trial 8 finished with value: 0.5608685258964143 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.017466029240814834, 'learning_rate': 0.0019409858132624915, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 43, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.3976439851917597}. Best is trial 3 with value: 0.7485059760956174.
# [I 2024-02-12 11:10:56,936] Trial 9 finished with value: 0.5967729083665338 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05183379233998096, 'learning_rate': 0.0036164486229221817, 'depth': 7, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 61, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.478119421437754}. Best is trial 3 with value: 0.7485059760956174.
# [I 2024-02-12 11:10:59,725] Trial 10 finished with value: 0.7544900398406373 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08660794841673079, 'learning_rate': 0.09572672133503776, 'depth': 4, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 97, 'bootstrap_type': 'MVS'}. Best is trial 10 with value: 0.7544900398406373.
# [I 2024-02-12 11:11:02,514] Trial 11 finished with value: 0.7495219123505976 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09090791870744823, 'learning_rate': 0.08944345759480539, 'depth': 4, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 98, 'bootstrap_type': 'MVS'}. Best is trial 10 with value: 0.7544900398406373.
# [I 2024-02-12 11:11:05,294] Trial 12 finished with value: 0.7684661354581674 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09318149536302223, 'learning_rate': 0.07595137828143106, 'depth': 4, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 100, 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:08,527] Trial 13 finished with value: 0.7564860557768924 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09720111488160196, 'learning_rate': 0.09518830986528512, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 98, 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:11,696] Trial 14 finished with value: 0.7475099601593624 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09971688312519714, 'learning_rate': 0.014548266864952605, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 83, 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:13,669] Trial 15 finished with value: 0.6566852589641434 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06680389140132059, 'learning_rate': 0.0616413292559465, 'depth': 1, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 83, 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:15,395] Trial 16 finished with value: 0.582812749003984 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.010795664323378664, 'learning_rate': 0.0157690759805034, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 93, 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:17,800] Trial 17 finished with value: 0.7565179282868526 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04395389309865443, 'learning_rate': 0.0584062689480899, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 71, 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:20,838] Trial 18 finished with value: 0.6676772908366534 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.040786437483624184, 'learning_rate': 0.006644503263933593, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 67, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.15658677186309689}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:22,706] Trial 19 finished with value: 0.6227609561752988 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.02814051148939303, 'learning_rate': 0.02165369011646361, 'depth': 3, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 74, 'bootstrap_type': 'Bernoulli', 'subsample': 0.10084998224450191}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:25,240] Trial 20 finished with value: 0.7554900398406375 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04635073808683258, 'learning_rate': 0.05078343903428765, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 18, 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:28,372] Trial 21 finished with value: 0.7445139442231075 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07615092020409936, 'learning_rate': 0.06100380989713975, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 89, 'bootstrap_type': 'MVS'}. Best is trial 12 with value: 0.7684661354581674.
# [I 2024-02-12 11:11:31,440] Trial 22 finished with value: 0.7564900398406376 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.
and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08865001458975462, 'learning_rate': 0.020112802675002983, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 64, 'bootstrap_type': 'MVS'}. Best is trial 41 with value: 0.7824342629482073.
# [I 2024-02-12 11:25:44,900] Trial 47 finished with value: 0.7654621513944222 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09048449948828335, 'learning_rate': 0.03144966664426242, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 80, 'bootstrap_type': 'MVS'}. Best is trial 41 with value: 0.7824342629482073.
# [I 2024-02-12 11:26:11,500] Trial 48 finished with value: 0.6227450199203187 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.07091673179654212, 'learning_rate': 0.0010153323684220842, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 47, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.29003240810195}. Best is trial 41 with value: 0.7824342629482073.
# [I 2024-02-12 11:26:18,258] Trial 49 finished with value: 0.6547091633466136 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.01841846850992251, 'learning_rate': 0.03316527691938196, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 96, 'bootstrap_type': 'MVS'}. Best is trial 41 with value: 0.7824342629482073.
# [I 2024-02-12 11:26:25,087] Trial 50 finished with value: 0.5618764940239044 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.013358530523581179, 'learning_rate': 0.009557125167158538, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 76, 'bootstrap_type': 'Bernoulli', 'subsample': 0.18314216152773236}. Best is trial 41 with value: 0.7824342629482073.
# [I 2024-02-12 11:27:49,085] Trial 51 finished with value: 0.7634581673306773 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09630964808457107, 'learning_rate': 0.04924513601811576, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 84, 'bootstrap_type': 'MVS'}. Best is trial 41 with value: 0.7824342629482073.
# [I 2024-02-12 11:29:25,069] Trial 52 finished with value: 0.7744501992031871 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09904051470686859, 'learning_rate': 0.02552992567687525, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 82, 'bootstrap_type': 'MVS'}. Best is trial 41 with value: 0.7824342629482073.
# [I 2024-02-12 11:30:16,787] Trial 53 finished with value: 0.7614661354581673 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0820306962776951, 'learning_rate': 0.02625651341868286, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 80, 'bootstrap_type': 'MVS'}. Best is trial 41 with value: 0.7824342629482073.
# Number of finished trials: 54
# Best trial:
#   Value: 0.7824342629482073
#   Params:
#     objective: CrossEntropy
#     colsample_bylevel: 0.09797183621012112
#     learning_rate: 0.049605700753321796
#     depth: 11
#     boosting_type: Ordered
#     l2_leaf_reg: 6
#     min_data_in_leaf: 92
#     bootstrap_type: MVS

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09797183621012112, 'learning_rate': 0.049605700753321796, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 92, 'bootstrap_type': 'MVS'}
# Best score: 0.7824342629482073

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x12a41fdd0>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.749003984063745

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.75       123
#            1       0.76      0.73      0.75       128
#
#     accuracy                           0.75       251
#    macro avg       0.75      0.75      0.75       251
# weighted avg       0.75      0.75      0.75       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_in"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price  exp_call    exp_date  final_price  \
# Date
# 2018-02-05         0   265.0        8.22  4.942161  2018-02-28   271.649994
# 2018-02-22         0   270.0        4.26  6.397086  2018-03-14   275.299988
# 2018-03-08         0   274.0        2.85  5.917690  2018-03-29   263.149994
# 2018-03-09         0   279.0        2.47  5.505012  2018-03-29   263.149994
# 2018-04-03         1   260.5        5.09  5.247430  2018-04-23   266.570007
# ...              ...     ...         ...       ...         ...          ...
# 2022-10-25         0   385.0       10.50  9.062317  2022-11-14   395.119995
# 2022-11-01         1   385.0        9.48  8.719475  2022-11-21   394.589996
# 2022-11-02         0   375.0       10.19  8.901524  2022-11-23   402.420013
# 2022-12-01         0   407.0        7.97  9.399281  2022-12-23   382.910004
# 2022-12-19         0   380.0        7.22  7.839602  2023-01-06   388.079987
#
#               profit       bare  cum_profit    cum_bare
# Date
# 2018-02-05  0.000000  -1.570006    0.000000   -1.570006
# 2018-02-22  0.000000   1.039988    0.000000   -0.530018
# 2018-03-08  0.000000  -2.850000    0.000000   -3.380018
# 2018-03-09  0.000000  -2.470000    0.000000   -5.850018
# 2018-04-03  0.980007   0.980007    0.980007   -4.870011
# ...              ...        ...         ...         ...
# 2022-10-25  0.000000  -0.380005  518.759861  389.189830
# 2022-11-01  0.109996   0.109996  518.869857  389.299827
# 2022-11-02  0.000000  17.230013  518.869857  406.529840
# 2022-12-01  0.000000  -7.970000  518.869857  398.559840
# 2022-12-19  0.000000   0.859987  518.869857  399.419827
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions +data (Buy only in-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x12a6985d0>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.4302788844621514

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.23      0.36       177
#            1       0.33      0.92      0.49        74
#
#     accuracy                           0.43       251
#    macro avg       0.60      0.57      0.42       251
# weighted avg       0.71      0.43      0.40       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = new_df.iloc[-i, :].to_dict()
    quote_date = new_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price   exp_call    exp_date  final_price  \
# Date
# 2022-01-03         0   478.0        4.81  10.248337  2022-01-24   439.839996
# 2022-01-04         0   478.0        4.80   9.610177  2022-01-24   439.839996
# 2022-01-05         1   468.0        8.14  10.191128  2022-01-26   433.380005
# 2022-01-06         1   468.0        7.00   9.657596  2022-01-26   433.380005
# 2022-01-07         1   466.0        7.56   9.927762  2022-01-28   441.950012
# ...              ...     ...         ...        ...         ...          ...
# 2022-12-23         1   383.0        8.00   8.453400  2023-01-13   398.500000
# 2022-12-26         1   383.0        7.96   8.096501  2023-01-13   398.500000
# 2022-12-28         1   377.0        8.75   8.526141  2023-01-20   395.880005
# 2022-12-29         1   383.0        8.50   8.908718  2023-01-20   395.880005
# 2022-12-30         1   382.0        8.21   8.652675  2023-01-20   395.880005
#
#                profit       bare  cum_profit    cum_bare
# Date
# 2022-01-03   0.000000  -4.810000    0.000000   -4.810000
# 2022-01-04   0.000000  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000  -8.140000   -8.140000  -17.750000
# 2022-01-06  -7.000000  -7.000000  -15.140000  -24.750000
# 2022-01-07  -7.560000  -7.560000  -22.700000  -32.310000
# ...               ...        ...         ...         ...
# 2022-12-23   7.500000   7.500000 -338.870012 -525.980022
# 2022-12-26   7.540000   7.540000 -331.330012 -518.440022
# 2022-12-28  10.130005  10.130005 -321.200007 -508.310017
# 2022-12-29   4.380005   4.380005 -316.820002 -503.930012
# 2022-12-30   5.670005   5.670005 -311.149998 -498.260007
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions + data (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## Compare the two predictions

# %%
mask_in = (compare_df["bare_rf_pred_in"] - compare_df["mmar_rf_pred_in"]).astype(bool)
mask_out = (compare_df["bare_rf_pred_out"] - compare_df["mmar_rf_pred_out"]).astype(
    bool
)

# %%
compare_df[mask_in]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 0                  0                 0                1                 0
# 3                  1                 0                0                 1
# 16                 0                 1                1                 1
# 21                 1                 1                0                 1
# 23                 1                 1                0                 1
# ..               ...               ...              ...               ...
# 237                1                 0                0                 1
# 238                1                 0                0                 1
# 246                0                 0                1                 1
# 247                1                 0                0                 1
# 250                1                 0                0                 1
#
# [62 rows x 4 columns]

# %%
compare_df[mask_in].shape
# Out:
# (62, 4)

# %%
# Compare out of sample preds
compare_df[mask_out]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 2                  0                 0                0                 1
# 3                  1                 0                0                 1
# 4                  1                 0                1                 1
# 5                  0                 0                0                 1
# 6                  0                 0                0                 1
# ..               ...               ...              ...               ...
# 246                0                 0                1                 1
# 247                1                 0                0                 1
# 248                1                 0                1                 1
# 249                0                 0                0                 1
# 250                1                 0                0                 1
#
# [176 rows x 4 columns]

# %%
compare_df[mask_out].shape
# Out:
# (176, 4)

# %%
compare_df.sum(axis=0)
# Out:
# bare_rf_pred_in     115
# bare_rf_pred_out     37
# mmar_rf_pred_in     123
# mmar_rf_pred_out    205
# dtype: int64
