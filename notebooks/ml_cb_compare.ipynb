# %% [markdown]
# ## Compare CatBoost in the case of binary class (Sell, Buy)

# %%
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
from catboost import CatBoostClassifier
from optuna.integration import CatBoostPruningCallback
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    accuracy_score,
    classification_report,
    confusion_matrix,
)
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
spy = pd.read_csv("../data/raw/spy.csv", parse_dates=True, index_col=0)

# %%
target = pd.read_csv("../data/processed/target_df.csv", parse_dates=True, index_col=0)[
    "target"
]

# %%
ml_df = pd.read_csv("../data/processed/ml_df.csv", parse_dates=True, index_col=0)

# %%
wk_df = pd.read_csv("../data/processed/exp_price.csv", parse_dates=True, index_col=0)

# %%
interest_rate = wk_df["r"].values

# %% [markdown]
# ### Functions

# %%
def display_report(y_test: np.ndarray, predictions: np.ndarray) -> None:
    print(classification_report(y_test, predictions))
    cm = confusion_matrix(y_test, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.show()
    return

# %%
def plot_feature_imp(coefficients: np.ndarray[float], columns: list[str]) -> None:
    feature_importance = pd.DataFrame(
        {"Feature": columns, "Importance": np.abs(coefficients)}
    )
    feature_importance = feature_importance.sort_values("Importance", ascending=True)
    feature_importance.plot(x="Feature", y="Importance", kind="barh", figsize=(10, 6))
    plt.show()
    return

# %% [markdown]
# ## Baseline Random Forest Classifier without new data + r

# %%
orig_df = ml_df[
    [
        "UNDERLYING_LAST",
        "STRIKE",
        "C_LAST",
        "C_BID",
        "C_ASK",
        "C_IV",
        "C_VOLUME",
        "diff_date",
    ]
].copy()

# %%
orig_df["r"] = interest_rate

# %% [markdown]
# ### In sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
# Adapted from https://github.com/optuna/optuna-examples/blob/main/catboost/catboost_pruning.py
def objective(trial: optuna.Trial) -> float:
    param = {
        "objective": trial.suggest_categorical(
            "objective", ["Logloss", "CrossEntropy"]
        ),
        "colsample_bylevel": trial.suggest_float(
            "colsample_bylevel", 0.01, 0.1, log=True
        ),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["Ordered", "Plain"]
        ),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 10),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    model = Pipeline(
        [
            ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
            ("rf", CatBoostClassifier(**param, silent=True)),
        ]
    )

    pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
    model.fit(
        X_train,
        y_train,
        rf__eval_set=[(X_test, y_test)],
        rf__early_stopping_rounds=100,
        rf__callbacks=[pruning_callback],
    )

    # evoke pruning manually.
    pruning_callback.check_pruned()

    preds = model.predict(X_test)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(y_test, pred_labels)

    return accuracy

# %%
study = optuna.create_study(
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), direction="maximize"
)
study.optimize(objective, n_trials=300, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 00:04:43,348] A new study created in memory with name: no-name-2507bcfb-2831-42ed-b0f0-8a441e31e636
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:04:43,753] Trial 0 finished with value: 0.545816733067729 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.05163563679481458, 'learning_rate': 0.020620392853406222, 'depth': 3, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 89, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.209861290270935}. Best is trial 0 with value: 0.545816733067729.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:04:43,886] Trial 1 finished with value: 0.49800796812749004 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04414506966034534, 'learning_rate': 0.024651286350320052, 'depth': 1, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 61, 'bootstrap_type': 'Bernoulli', 'subsample': 0.354889612425712}. Best is trial 0 with value: 0.545816733067729.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:04:44,132] Trial 2 finished with value: 0.5338645418326693 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.02180251616925489, 'learning_rate': 0.021917131194249873, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 81, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.545816733067729.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:04

# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:32,014] Trial 276 pruned. Trial was pruned at iteration 91.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:32,096] Trial 277 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:32,468] Trial 278 finished with value: 0.6613545816733067 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08418410547138275, 'learning_rate': 0.08062611847280944, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 69, 'bootstrap_type': 'Bernoulli', 'subsample': 0.29425346993125123}. Best is trial 65 with value: 0.7091633466135459.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:32,544] Trial 279 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:32,622] Trial 280 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:32,696] Trial 281 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:32,858] Trial 282 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:32,944] Trial 283 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:33,020] Trial 284 pruned. Trial was pruned at iteration 7.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:33,093] Trial 285 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:33,181] Trial 286 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:33,394] Trial 287 pruned. Trial was pruned at iteration 115.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:33,483] Trial 288 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:33,569] Trial 289 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:33,651] Trial 290 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:33,992] Trial 291 finished with value: 0.649402390438247 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08661630591711063, 'learning_rate': 0.08960326642019462, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 60, 'bootstrap_type': 'Bernoulli', 'subsample': 0.25955663454884387}. Best is trial 65 with value: 0.7091633466135459.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:34,098] Trial 292 pruned. Trial was pruned at iteration 29.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:34,179] Trial 293 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:34,259] Trial 294 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:34,399] Trial 295 pruned. Trial was pruned at iteration 78.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:34,474] Trial 296 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:34,821] Trial 297 finished with value: 0.6733067729083665 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08925064996450124, 'learning_rate': 0.08971395356559698, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 87, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2783141598126229}. Best is trial 65 with value: 0.7091633466135459.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:34,900] Trial 298 pruned. Trial was pruned at iteration 5.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:34,978] Trial 299 pruned. Trial was pruned at iteration 5.
# Number of finished trials: 300
# Best trial:
#   Value: 0.7091633466135459
#   Params:
#     objective: CrossEntropy
#     colsample_bylevel: 0.0914443313497097
#     learning_rate: 0.06883138756989055
#     depth: 11
#     boosting_type: Plain
#     l2_leaf_reg: 2
#     min_data_in_leaf: 55
#     bootstrap_type: MVS

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0914443313497097, 'learning_rate': 0.06883138756989055, 'depth': 11, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 55, 'bootstrap_type': 'MVS'}
# Best score: 0.7091633466135459

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x16908a940>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6972111553784861

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.70      0.69       123
#            1       0.71      0.70      0.70       128
#
#     accuracy                           0.70       251
#    macro avg       0.70      0.70      0.70       251
# weighted avg       0.70      0.70      0.70       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df = pd.DataFrame(predictions, columns=["bare_rf_pred_in"])

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price     profit  \
# Date
# 2018-02-05         1   265.0        8.22  2018-02-28   271.649994  -1.570006
# 2018-02-22         0   270.0        4.26  2018-03-14   275.299988   0.000000
# 2018-03-08         0   274.0        2.85  2018-03-29   263.149994   0.000000
# 2018-03-09         0   279.0        2.47  2018-03-29   263.149994   0.000000
# 2018-04-03         1   260.5        5.09  2018-04-23   266.570007   0.980007
# ...              ...     ...         ...         ...          ...        ...
# 2022-10-25         0   385.0       10.50  2022-11-14   395.119995   0.000000
# 2022-11-01         1   385.0        9.48  2022-11-21   394.589996   0.109996
# 2022-11-02         1   375.0       10.19  2022-11-23   402.420013  17.230013
# 2022-12-01         0   407.0        7.97  2022-12-23   382.910004   0.000000
# 2022-12-19         0   380.0        7.22  2023-01-06   388.079987   0.000000
#
#                  bare  cum_profit    cum_bare
# Date
# 2018-02-05  -1.570006   -1.570006   -1.570006
# 2018-02-22   1.039988   -1.570006   -0.530018
# 2018-03-08  -2.850000   -1.570006   -3.380018
# 2018-03-09  -2.470000   -1.570006   -5.850018
# 2018-04-03   0.980007   -0.589999   -4.870011
# ...               ...         ...         ...
# 2022-10-25  -0.380005  394.289916  389.189830
# 2022-11-01   0.109996  394.399912  389.299827
# 2022-11-02  17.230013  411.629926  406.529840
# 2022-12-01  -7.970000  411.629926  398.559840
# 2022-12-19   0.859987  411.629926  399.419827
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only in sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x168d50700>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6095617529880478

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.84      0.75       177
#            1       0.15      0.07      0.09        74
#
#     accuracy                           0.61       251
#    macro avg       0.41      0.45      0.42       251
# weighted avg       0.52      0.61      0.56       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["bare_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = orig_df.iloc[-i, :].to_dict()
    quote_date = orig_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price  profit  \
# Date
# 2022-01-03         0   478.0        4.81  2022-01-24   439.839996     0.0
# 2022-01-04         0   478.0        4.80  2022-01-24   439.839996     0.0
# 2022-01-05         0   468.0        8.14  2022-01-26   433.380005     0.0
# 2022-01-06         0   468.0        7.00  2022-01-26   433.380005     0.0
# 2022-01-07         0   466.0        7.56  2022-01-28   441.950012     0.0
# ...              ...     ...         ...         ...          ...     ...
# 2022-12-23         0   383.0        8.00  2023-01-13   398.500000     0.0
# 2022-12-26         0   383.0        7.96  2023-01-13   398.500000     0.0
# 2022-12-28         0   377.0        8.75  2023-01-20   395.880005     0.0
# 2022-12-29         0   383.0        8.50  2023-01-20   395.880005     0.0
# 2022-12-30         0   382.0        8.21  2023-01-20   395.880005     0.0
#
#                  bare  cum_profit    cum_bare
# Date
# 2022-01-03  -4.810000    0.000000   -4.810000
# 2022-01-04  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000    0.000000  -17.750000
# 2022-01-06  -7.000000    0.000000  -24.750000
# 2022-01-07  -7.560000    0.000000  -32.310000
# ...               ...         ...         ...
# 2022-12-23   7.500000 -208.750006 -525.980022
# 2022-12-26   7.540000 -208.750006 -518.440022
# 2022-12-28  10.130005 -208.750006 -508.310017
# 2022-12-29   4.380005 -208.750006 -503.930012
# 2022-12-30   5.670005 -208.750006 -498.260007
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## CatBoost with data from MC simulation and additional features

# %%
new_df = pd.concat(
    (
        ml_df[
            [
                "UNDERLYING_LAST",
                "STRIKE",
                "C_LAST",
                "C_BID",
                "C_ASK",
                "C_IV",
                "C_VOLUME",
                "diff",
            ]
        ],
        wk_df.drop(["last_quote", "strike"], axis=1),
    ),
    axis=1,
)

# %%
# Add some features
new_df["iqr"] = new_df["exp_price_q3"] - new_df["exp_price_q1"]
new_df["diff_call"] = new_df["exp_call_price"] - new_df["C_LAST"]
new_df["exp_price_var"] = np.power(new_df["exp_price_std"], 2)
new_df["exp_profit"] = new_df["exp_price"] - (new_df["STRIKE"] + new_df["C_LAST"])

# %% [markdown]
# ### In-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
study = optuna.create_study(
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), direction="maximize"
)
study.optimize(objective, n_trials=300, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 00:05:38,698] A new study created in memory with name: no-name-7782bd1c-6813-4812-9f89-93ec3c30cd41
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:38,926] Trial 0 finished with value: 0.6772908366533864 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.049929433709981305, 'learning_rate': 0.025722165184218937, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 8, 'min_data_in_leaf': 71, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.6772908366533864.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:40,232] Trial 1 finished with value: 0.6613545816733067 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.01051799163803851, 'learning_rate': 0.09173577876932876, 'depth': 3, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 69, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.6772908366533864.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05:40,778] Trial 2 finished with value: 0.7330677290836654 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.059807791777621105, 'learning_rate': 0.08839863198220585, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 52, 'bootstrap_type': 'MVS'}. Best is trial 2 with value: 0.7330677290836654.
# /var/folders/x8/wry4p1zj0pv6lw6tw9wysqh40000gn/T/ipykernel_71372/2739073107.py:33: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:05
ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2024-02-12 00:07:32,365] Trial 299 pruned. Trial was pruned at iteration 5.
# Number of finished trials: 300
# Best trial:
#   Value: 0.7808764940239044
#   Params:
#     objective: CrossEntropy
#     colsample_bylevel: 0.093569134749942
#     learning_rate: 0.07181824159289617
#     depth: 12
#     boosting_type: Plain
#     l2_leaf_reg: 4
#     min_data_in_leaf: 10
#     bootstrap_type: MVS

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.093569134749942, 'learning_rate': 0.07181824159289617, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 10, 'bootstrap_type': 'MVS'}
# Best score: 0.7808764940239044

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x168ee4ac0>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.7569721115537849

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76       123
#            1       0.78      0.73      0.76       128
#
#     accuracy                           0.76       251
#    macro avg       0.76      0.76      0.76       251
# weighted avg       0.76      0.76      0.76       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_in"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price  exp_call    exp_date  final_price  \
# Date
# 2018-02-05         0   265.0        8.22  4.942161  2018-02-28   271.649994
# 2018-02-22         0   270.0        4.26  6.397086  2018-03-14   275.299988
# 2018-03-08         0   274.0        2.85  5.917690  2018-03-29   263.149994
# 2018-03-09         0   279.0        2.47  5.505012  2018-03-29   263.149994
# 2018-04-03         1   260.5        5.09  5.247430  2018-04-23   266.570007
# ...              ...     ...         ...       ...         ...          ...
# 2022-10-25         0   385.0       10.50  9.062317  2022-11-14   395.119995
# 2022-11-01         1   385.0        9.48  8.719475  2022-11-21   394.589996
# 2022-11-02         0   375.0       10.19  8.901524  2022-11-23   402.420013
# 2022-12-01         0   407.0        7.97  9.399281  2022-12-23   382.910004
# 2022-12-19         0   380.0        7.22  7.839602  2023-01-06   388.079987
#
#               profit       bare  cum_profit    cum_bare
# Date
# 2018-02-05  0.000000  -1.570006    0.000000   -1.570006
# 2018-02-22  0.000000   1.039988    0.000000   -0.530018
# 2018-03-08  0.000000  -2.850000    0.000000   -3.380018
# 2018-03-09  0.000000  -2.470000    0.000000   -5.850018
# 2018-04-03  0.980007   0.980007    0.980007   -4.870011
# ...              ...        ...         ...         ...
# 2022-10-25  0.000000  -0.380005  638.009824  389.189830
# 2022-11-01  0.109996   0.109996  638.119821  389.299827
# 2022-11-02  0.000000  17.230013  638.119821  406.529840
# 2022-12-01  0.000000  -7.970000  638.119821  398.559840
# 2022-12-19  0.000000   0.859987  638.119821  399.419827
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on Random Forest predictions +data (Buy only in-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x16962de50>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.4103585657370518

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.20      0.32       177
#            1       0.32      0.92      0.48        74
#
#     accuracy                           0.41       251
#    macro avg       0.59      0.56      0.40       251
# weighted avg       0.70      0.41      0.37       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = new_df.iloc[-i, :].to_dict()
    quote_date = new_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price   exp_call    exp_date  final_price  \
# Date
# 2022-01-03         0   478.0        4.81  10.248337  2022-01-24   439.839996
# 2022-01-04         0   478.0        4.80   9.610177  2022-01-24   439.839996
# 2022-01-05         1   468.0        8.14  10.191128  2022-01-26   433.380005
# 2022-01-06         1   468.0        7.00   9.657596  2022-01-26   433.380005
# 2022-01-07         1   466.0        7.56   9.927762  2022-01-28   441.950012
# ...              ...     ...         ...        ...         ...          ...
# 2022-12-23         1   383.0        8.00   8.453400  2023-01-13   398.500000
# 2022-12-26         1   383.0        7.96   8.096501  2023-01-13   398.500000
# 2022-12-28         1   377.0        8.75   8.526141  2023-01-20   395.880005
# 2022-12-29         1   383.0        8.50   8.908718  2023-01-20   395.880005
# 2022-12-30         1   382.0        8.21   8.652675  2023-01-20   395.880005
#
#                profit       bare  cum_profit    cum_bare
# Date
# 2022-01-03   0.000000  -4.810000    0.000000   -4.810000
# 2022-01-04   0.000000  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000  -8.140000   -8.140000  -17.750000
# 2022-01-06  -7.000000  -7.000000  -15.140000  -24.750000
# 2022-01-07  -7.560000  -7.560000  -22.700000  -32.310000
# ...               ...        ...         ...         ...
# 2022-12-23   7.500000   7.500000 -355.650016 -525.980022
# 2022-12-26   7.540000   7.540000 -348.110016 -518.440022
# 2022-12-28  10.130005  10.130005 -337.980011 -508.310017
# 2022-12-29   4.380005   4.380005 -333.600006 -503.930012
# 2022-12-30   5.670005   5.670005 -327.930001 -498.260007
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on Random Forest predictions + data (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## Compare the two predictions

# %%
mask_in = (compare_df["bare_rf_pred_in"] - compare_df["mmar_rf_pred_in"]).astype(bool)
mask_out = (compare_df["bare_rf_pred_out"] - compare_df["mmar_rf_pred_out"]).astype(
    bool
)

# %%
compare_df[mask_in]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 2                  1                 0                0                 1
# 3                  1                 0                0                 1
# 16                 0                 1                1                 1
# 21                 1                 1                0                 1
# 24                 0                 1                1                 1
# 40                 0                 1                1                 1
# 46                 1                 0                0                 1
# 47                 0                 0                1                 1
# 50                 0                 0                1                 1
# 51                 1                 0                0                 1
# 55                 0                 0                1                 1
# 69                 1                 0                0                 1
# 77                 1                 0                0                 1
# 78                 1                 0                0                 1
# 88                 0                 0                1                 1
# 99                 0                 0                1                 1
# 103                0                 0                1                 1
# 115                0                 0                1                 1
# 117                1                 0                0                 1
# 131                0                 0                1                 1
# 132                0                 0                1                 1
# 137                1                 0                0                 0
# 139                1                 0                0                 1
# 141                0                 0                1                 1
# 142                1                 0                0                 1
# 158                1                 0                0                 0
# 159                0                 0                1                 0
# 160                1                 0                0                 0
# 168                1                 0                0                 0
# 171                0                 0                1                 1
# 175                1                 0                0                 0
# 187                1                 0                0                 1
# 194                1                 0                0                 1
# 195                1                 0                0                 1
# 196                1                 0                0                 1
# 199                0                 0                1                 1
# 200                0                 0                1                 1
# 202                1                 0                0                 1
# 208                1                 0                0                 1
# 212                1                 0                0                 1
# 213                1                 0                0                 1
# 216                0                 0                1                 1
# 231                0                 0                1                 1
# 232                1                 0                0                 1
# 237                1                 0                0                 1
# 246                0                 0                1                 1
# 247                0                 0                1                 1

# %%
compare_df[mask_in].shape
# Out:
# (47, 4)

# %%
# Compare out of sample preds
compare_df[mask_out]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 2                  1                 0                0                 1
# 3                  1                 0                0                 1
# 4                  1                 0                1                 1
# 5                  0                 0                0                 1
# 6                  0                 0                0                 1
# ..               ...               ...              ...               ...
# 246                0                 0                1                 1
# 247                0                 0                1                 1
# 248                1                 0                1                 1
# 249                0                 0                0                 1
# 250                1                 0                1                 1
#
# [184 rows x 4 columns]

# %%
compare_df[mask_out].shape
# Out:
# (184, 4)

# %%
compare_df.sum(axis=0)
# Out:
# bare_rf_pred_in     126
# bare_rf_pred_out     34
# mmar_rf_pred_in     121
# mmar_rf_pred_out    210
# dtype: int64
