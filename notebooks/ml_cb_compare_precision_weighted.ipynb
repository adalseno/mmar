# %% [markdown]
# ## Compare CatBoost in the case of binary class (Sell, Buy)

# %%
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    classification_report,
    confusion_matrix,
)
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.pipeline import Pipeline

# %%
spy = pd.read_csv("../data/raw/spy.csv", parse_dates=True, index_col=0)

# %%
target = pd.read_csv("../data/processed/target_df.csv", parse_dates=True, index_col=0)[
    "target"
]

# %%
ml_df = pd.read_csv("../data/processed/ml_df.csv", parse_dates=True, index_col=0)

# %%
wk_df = pd.read_csv("../data/processed/exp_price.csv", parse_dates=True, index_col=0)

# %%
interest_rate = wk_df["r"].values

# %% [markdown]
# ### Functions

# %%
def display_report(y_test: np.ndarray, predictions: np.ndarray) -> None:
    print(classification_report(y_test, predictions))
    cm = confusion_matrix(y_test, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.show()
    return

# %%
def plot_feature_imp(coefficients: np.ndarray[float], columns: list[str]) -> None:
    feature_importance = pd.DataFrame(
        {"Feature": columns, "Importance": np.abs(coefficients)}
    )
    feature_importance = feature_importance.sort_values("Importance", ascending=True)
    feature_importance.plot(x="Feature", y="Importance", kind="barh", figsize=(10, 6))
    plt.show()
    return

# %% [markdown]
# ## Baseline CatBoost Classifier without new data + r

# %%
orig_df = ml_df[
    [
        "UNDERLYING_LAST",
        "STRIKE",
        "C_LAST",
        "C_BID",
        "C_ASK",
        "C_IV",
        "C_VOLUME",
        "diff_date",
    ]
].copy()

# %%
orig_df["r"] = interest_rate

# %% [markdown]
# ### In sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
# Adapted from https://github.com/optuna/optuna-examples/blob/main/catboost/catboost_pruning.py
def objective(trial: optuna.Trial) -> float:
    param = {
        "objective": trial.suggest_categorical(
            "objective", ["Logloss", "CrossEntropy"]
        ),
        "colsample_bylevel": trial.suggest_float(
            "colsample_bylevel", 0.01, 0.1, log=True
        ),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["Ordered", "Plain"]
        ),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 10),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    model = Pipeline(
        [
            ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
            (
                "rf",
                CatBoostClassifier(
                    **param, silent=True, early_stopping_rounds=50, random_state=1968
                ),
            ),
        ]
    )

    cv = StratifiedKFold(n_splits=4, shuffle=True, random_state=1968)

    return cross_val_score(
        model, X_train, y_train, cv=cv, scoring="precision_weighted", n_jobs=1
    ).mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 10:29:40,989] A new study created in memory with name: no-name-6b06404d-2805-4414-8198-ba7296a8469c
# [I 2024-02-12 10:29:43,663] Trial 0 finished with value: 0.6995328333301675 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05431463044969563, 'learning_rate': 0.0014450450201364167, 'depth': 11, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 15, 'bootstrap_type': 'Bernoulli', 'subsample': 0.38633184858130665}. Best is trial 0 with value: 0.6995328333301675.
# [I 2024-02-12 10:29:45,921] Trial 1 finished with value: 0.6071079333518277 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.025672002828088073, 'learning_rate': 0.013705669364913822, 'depth': 7, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 82, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.6995328333301675.
# [I 2024-02-12 10:29:47,848] Trial 2 finished with value: 0.6024799391020134 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05228540650562491, 'learning_rate': 0.0032479897711841185, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 76, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.6995328333301675.
# [I 2024-02-12 10:29:49,496] Trial 3 finished with value: 0.7202238638776426 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.015381420395041107, 'learning_rate': 0.009626448866062912, 'depth': 9, 'boosting_type': 'Plain', 'l2_leaf_reg': 6, 'min_data_in_leaf': 76, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.087701711705656}. Best is trial 3 with value: 0.7202238638776426.
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 2024-02-12 10:29:51,153] Trial 4 finished with value: 0.2745278850811892 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0
and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04460719354470208, 'learning_rate': 0.0018902529515303517, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 11, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7514983673581078}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:34:23,556] Trial 68 finished with value: 0.5835574114794233 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03358269777566677, 'learning_rate': 0.030044573859754627, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 33, 'bootstrap_type': 'Bernoulli', 'subsample': 0.24367064398863691}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:34:30,986] Trial 69 finished with value: 0.6129478112175737 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08124732774304463, 'learning_rate': 0.002855677933288912, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 43, 'bootstrap_type': 'Bernoulli', 'subsample': 0.19626352410295408}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:34:37,565] Trial 70 finished with value: 0.6624029532400659 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.057420802846319924, 'learning_rate': 0.0013513035794513093, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 3, 'min_data_in_leaf': 6, 'bootstrap_type': 'MVS'}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:34:44,476] Trial 71 finished with value: 0.7046451096941949 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06624668564711546, 'learning_rate': 0.001108778401941297, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 3, 'min_data_in_leaf': 16, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3985115305411496}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:34:51,625] Trial 72 finished with value: 0.6143344501610343 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08619080962819865, 'learning_rate': 0.0015865727088687923, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 13, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3332058740269171}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:34:58,887] Trial 73 finished with value: 0.6256735166171922 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09613342547002537, 'learning_rate': 0.0012174470298099988, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 3, 'min_data_in_leaf': 24, 'bootstrap_type': 'Bernoulli', 'subsample': 0.42844234518252117}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:06,111] Trial 74 finished with value: 0.7190634375705555 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05286500647127011, 'learning_rate': 0.0013750225698803257, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 22, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3425208607499061}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:13,377] Trial 75 finished with value: 0.6934238378182955 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.051045799216851484, 'learning_rate': 0.002254140632248831, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 27, 'bootstrap_type': 'Bernoulli', 'subsample': 0.31767190067342066}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:20,550] Trial 76 finished with value: 0.7290836320798171 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.052522298134889525, 'learning_rate': 0.001465094470105458, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 19, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2607244339847398}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:22,525] Trial 77 finished with value: 0.7138825103096387 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05359220327008442, 'learning_rate': 0.0018723263120160928, 'depth': 11, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 52, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.283587105349843}. Best is trial 23 with value: 0.7533477654871432.
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 2024-02-12 10:35:28,747] Trial 78 finished with value: 0.5139151985198727 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.029602739522833706, 'learning_rate': 0.0013946384154498242, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 22, 'bootstrap_type': 'Bernoulli', 'subsample': 0.25862159742076607}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:30,727] Trial 79 finished with value: 0.5721000035676995 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06124454294951761, 'learning_rate': 0.024898316198692618, 'depth': 8, 'boosting_type': 'Plain', 'l2_leaf_reg': 6, 'min_data_in_leaf': 20, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.645943466869447}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:32,559] Trial 80 finished with value: 0.5835692423164593 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07446997928910704, 'learning_rate': 0.01253688759011847, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 7, 'min_data_in_leaf': 73, 'bootstrap_type': 'Bernoulli', 'subsample': 0.20495076354493705}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:39,017] Trial 81 finished with value: 0.7251273673021235 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04731334019839312, 'learning_rate': 0.0014025375017548494, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 31, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3433533385985528}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:45,222] Trial 82 finished with value: 0.7136023581612776 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04216467312658819, 'learning_rate': 0.0016135947967342754, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 78, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3441226833288759}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:51,557] Trial 83 finished with value: 0.7236681813979138 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05088299586149797, 'learning_rate': 0.0014299101772485133, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 31, 'bootstrap_type': 'Bernoulli', 'subsample': 0.10061620009893446}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:35:58,811] Trial 84 finished with value: 0.7045057734618241 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.055037222862386985, 'learning_rate': 0.0013655651167009493, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 35, 'bootstrap_type': 'Bernoulli', 'subsample': 0.10951243173580025}. Best is trial 23 with value: 0.7533477654871432.
# ...
# [I 2024-02-12 10:37:24,814] Trial 102 finished with value: 0.6886570794320384 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05429644428345037, 'learning_rate': 0.0014686950200495084, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 12, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6029409043292779}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:37:26,555] Trial 103 finished with value: 0.7042300948545448 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 2024-02-12 10:39:19,229] Trial 124 finished with value: 0.5876485641415374 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05992943451426178, 'learning_rate': 0.002097481531804735, 'depth': 1, 'boosting_type': 'Ordered', 'l2_leaf_reg': 3, 'min_data_in_leaf': 60, 'bootstrap_type': 'Bernoulli', 'subsample': 0.27696905557351076}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:39:25,825] Trial 125 finished with value: 0.6764423204520903 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05645935190377357, 'learning_rate': 0.0015216645175495959, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 6, 'bootstrap_type': 'Bernoulli', 'subsample': 0.8429871479807851}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:39:32,111] Trial 126 finished with value: 0.6989651768088857 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04311673094268393, 'learning_rate': 0.0019047275778370286, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 11, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4092692995982968}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:39:33,987] Trial 127 finished with value: 0.7012715481803127 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.04902065838283341, 'learning_rate': 0.0011887202232566418, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 8, 'min_data_in_leaf': 1, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2887532110288715}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:39:40,323] Trial 128 finished with value: 0.5521051979928437 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.036760001347338235, 'learning_rate': 0.017485429839603335, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 5, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.874748099304515}. Best is trial 23 with value: 0.7533477654871432.
# [I 2024-02-12 10:39:46,843] Trial 129 finished with value: 0.6040526300385075 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03842346808175656, 'learning_rate': 0.007069151481253114, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 3, 'min_data_in_leaf': 9, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4898603727053853}. Best is trial 23 with value: 0.7533477654871432.
# Number of finished trials: 130
# Best trial:
#   Value: 0.7533477654871432
#   Params:
#     objective: Logloss
#     colsample_bylevel: 0.0494213226673415
#     learning_rate: 0.001253127719702948
#     depth: 5
#     boosting_type: Plain
#     l2_leaf_reg: 7
#     min_data_in_leaf: 69
#     bootstrap_type: Bayesian
#     bagging_temperature: 7.320992229938124

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0494213226673415, 'learning_rate': 0.001253127719702948, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 7, 'min_data_in_leaf': 69, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.320992229938124}
# Best score: 0.7533477654871432

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x137be4790>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.4940239043824701

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66       123
#            1       1.00      0.01      0.02       128
#
#     accuracy                           0.49       251
#    macro avg       0.75      0.50      0.34       251
# weighted avg       0.75      0.49      0.33       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df = pd.DataFrame(predictions, columns=["bare_rf_pred_in"])

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price  profit  \
# Date
# 2018-02-05         0   265.0        8.22  2018-02-28   271.649994     0.0
# 2018-02-22         0   270.0        4.26  2018-03-14   275.299988     0.0
# 2018-03-08         0   274.0        2.85  2018-03-29   263.149994     0.0
# 2018-03-09         0   279.0        2.47  2018-03-29   263.149994     0.0
# 2018-04-03         0   260.5        5.09  2018-04-23   266.570007     0.0
# ...              ...     ...         ...         ...          ...     ...
# 2022-10-25         0   385.0       10.50  2022-11-14   395.119995     0.0
# 2022-11-01         0   385.0        9.48  2022-11-21   394.589996     0.0
# 2022-11-02         0   375.0       10.19  2022-11-23   402.420013     0.0
# 2022-12-01         0   407.0        7.97  2022-12-23   382.910004     0.0
# 2022-12-19         0   380.0        7.22  2023-01-06   388.079987     0.0
#
#                  bare  cum_profit    cum_bare
# Date
# 2018-02-05  -1.570006    0.000000   -1.570006
# 2018-02-22   1.039988    0.000000   -0.530018
# 2018-03-08  -2.850000    0.000000   -3.380018
# 2018-03-09  -2.470000    0.000000   -5.850018
# 2018-04-03   0.980007    0.000000   -4.870011
# ...               ...         ...         ...
# 2022-10-25  -0.380005   20.770012  389.189830
# 2022-11-01   0.109996   20.770012  389.299827
# 2022-11-02  17.230013   20.770012  406.529840
# 2022-12-01  -7.970000   20.770012  398.559840
# 2022-12-19   0.859987   20.770012  399.419827
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only in sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x137fd9fd0>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.2948207171314741

# %%
display_report(y_test, predictions)
# Out:
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/andrea/Desktop/WQU-Course/MScFE/Capstone/wqu_capstone/.venv/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       177
#            1       0.29      1.00      0.46        74
#
#     accuracy                           0.29       251
#    macro avg       0.15      0.50      0.23       251
# weighted avg       0.09      0.29      0.13       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["bare_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = orig_df.iloc[-i, :].to_dict()
    quote_date = orig_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price     profit  \
# Date
# 2022-01-03         1   478.0        4.81  2022-01-24   439.839996  -4.810000
# 2022-01-04         1   478.0        4.80  2022-01-24   439.839996  -4.800000
# 2022-01-05         1   468.0        8.14  2022-01-26   433.380005  -8.140000
# 2022-01-06         1   468.0        7.00  2022-01-26   433.380005  -7.000000
# 2022-01-07         1   466.0        7.56  2022-01-28   441.950012  -7.560000
# ...              ...     ...         ...         ...          ...        ...
# 2022-12-23         1   383.0        8.00  2023-01-13   398.500000   7.500000
# 2022-12-26         1   383.0        7.96  2023-01-13   398.500000   7.540000
# 2022-12-28         1   377.0        8.75  2023-01-20   395.880005  10.130005
# 2022-12-29         1   383.0        8.50  2023-01-20   395.880005   4.380005
# 2022-12-30         1   382.0        8.21  2023-01-20   395.880005   5.670005
#
#                  bare  cum_profit    cum_bare
# Date
# 2022-01-03  -4.810000   -4.810000   -4.810000
# 2022-01-04  -4.800000   -9.610000   -9.610000
# 2022-01-05  -8.140000  -17.750000  -17.750000
# 2022-01-06  -7.000000  -24.750000  -24.750000
# 2022-01-07  -7.560000  -32.310000  -32.310000
# ...               ...         ...         ...
# 2022-12-23   7.500000 -525.980022 -525.980022
# 2022-12-26   7.540000 -518.440022 -518.440022
# 2022-12-28  10.130005 -508.310017 -508.310017
# 2022-12-29   4.380005 -503.930012 -503.930012
# 2022-12-30   5.670005 -498.260007 -498.260007
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## CatBoost with data from MC simulation and additional features

# %%
new_df = pd.concat(
    (
        ml_df[
            [
                "UNDERLYING_LAST",
                "STRIKE",
                "C_LAST",
                "C_BID",
                "C_ASK",
                "C_IV",
                "C_VOLUME",
                "diff",
            ]
        ],
        wk_df.drop(["last_quote", "strike"], axis=1),
    ),
    axis=1,
)

# %%
# Add some features
new_df["iqr"] = new_df["exp_price_q3"] - new_df["exp_price_q1"]
new_df["diff_call"] = new_df["exp_call_price"] - new_df["C_LAST"]
new_df["exp_price_var"] = np.power(new_df["exp_price_std"], 2)
new_df["exp_profit"] = new_df["exp_price"] - (new_df["STRIKE"] + new_df["C_LAST"])

# %% [markdown]
# ### In-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, timeout=1200)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 10:39:53,714] A new study created in memory with name: no-name-634d0ccd-48d5-47e2-84bc-916ef9111856
# [I 2024-02-12 10:40:13,969] Trial 0 finished with value: 0.7597342927765648 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07283042585048866, 'learning_rate': 0.022718834080503892, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 41, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5390390848566042}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:40:16,150] Trial 1 finished with value: 0.6019458535698295 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0724360187891832, 'learning_rate': 0.005343623997826661, 'depth': 3, 'boosting_type': 'Plain', 'l2_leaf_reg': 5, 'min_data_in_leaf': 67, 'bootstrap_type': 'Bernoulli', 'subsample': 0.10175279158233926}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:40:25,718] Trial 2 finished with value: 0.7474605855642793 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0551858034366915, 'learning_rate': 0.03557572174115039, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 58, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6698784378376418}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:40:33,677] Trial 3 finished with value: 0.7252083608251249 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.04143394138936381, 'learning_rate': 0.03270105924164915, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 3, 'min_data_in_leaf': 36, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:40:36,222] Trial 4 finished with value: 0.7095117361907389 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.05140737072224536, 'learning_rate': 0.09595144164069555, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 25, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.163472608704117}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:40:43,406] Trial 5 finished with value: 0.6233327237500083 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08004978068672701, 'learning_rate': 0.01655782991301535, 'depth': 2, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 63, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.42124815541122}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:40:49,838] Trial 6 finished with value: 0.6744640693383662 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.020452443961968967, 'learning_rate': 0.0015957090616585793, 'depth': 3, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 67, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.484959790769903}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:40:56,636] Trial 7 finished with value: 0.6281134568634282 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.029458412907012094, 'learning_rate': 0.0018476622174532916, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 22, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.398324815126557}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:40:58,958] Trial 8 finished with value: 0.69141285089604 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07582910148716683, 'learning_rate': 0.016958036960090118, 'depth': 3, 'boosting_type': 'Plain', 'l2_leaf_reg': 3, 'min_data_in_leaf': 50, 'bootstrap_type': 'Bernoulli', 'subsample': 0.30187038567193114}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:41:06,369] Trial 9 finished with value: 0.6629469845239853 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07018337936906957, 'learning_rate': 0.01294169069462087, 'depth': 3, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 40, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.822608350930498}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:41:08,051] Trial 10 finished with value: 0.6102175459781369 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.011383196619795833, 'learning_rate': 0.004976876590558865, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 7, 'min_data_in_leaf': 97, 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.7597342927765648.
# [I 2024-02-12 10:41:38,357] Trial 11 finished with value: 0.7718443735551433 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0991169702352812, 'learning_rate': 0.05777169987060353, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 7, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7998275893656088}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:41:45,736] Trial 12 finished with value: 0.727924727249161 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.031126723847272112, 'learning_rate': 0.07939178455485521, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 1, 'bootstrap_type': 'Bernoulli', 'subsample': 0.898900905778104}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:42:13,951] Trial 13 finished with value: 0.7611919330368692 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09317064185183127, 'learning_rate': 0.03999779553981524, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 3, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4821790734674404}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:42:33,534] Trial 14 finished with value: 0.7419345175665311 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09899746229821386, 'learning_rate': 0.05145478366600357, 'depth': 6, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 6, 'bootstrap_type': 'Bernoulli', 'subsample': 0.3561914312716764}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:42:50,556] Trial 15 finished with value: 0.7502557270962502 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09654955745305258, 'learning_rate': 0.051662362447450864, 'depth': 7, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 15, 'bootstrap_type': 'Bernoulli', 'subsample': 0.43502079268671084}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:42:57,369] Trial 16 finished with value: 0.5996166700730393 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.019838762166481925, 'learning_rate': 0.006088532207546738, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 12, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9191620897301648}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:43:07,294] Trial 17 finished with value: 0.7392271824694252 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04750203592914928, 'learning_rate': 0.05582380476754292, 'depth': 5, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 88, 'bootstrap_type': 'MVS'}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:43:09,940] Trial 18 finished with value: 0.6993758430212091 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03902854334340064, 'learning_rate': 0.030906047545932284, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 8, 'min_data_in_leaf': 26, 'bootstrap_type': 'Bernoulli', 'subsample': 0.1999910211618891}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:43:23,795] Trial 19 finished with value: 0.6995094920477236 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06058402131145457, 'learning_rate': 0.008431556386613206, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 1, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6221380909811245}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:43:30,935] Trial 20 finished with value: 0.7056200790501195 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.011512730233591397, 'learning_rate': 0.0028843581231725117, 'depth': 5, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 13, 'bootstrap_type': 'MVS'}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:44:01,739] Trial 21 finished with value: 0.7561574015063109 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09913889288578906, 'learning_rate': 0.02291037277231348, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 37, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5260485502443585}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:44:38,116] Trial 22 finished with value: 0.7526496254894388 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08302507715081427, 'learning_rate': 0.02378812137812908, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 80, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6173435554982368}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:44:49,817] Trial 23 finished with value: 0.7607930815575241 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06292560496768057, 'learning_rate': 0.0608344445561905, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 48, 'bootstrap_type': 'Bernoulli', 'subsample': 0.4154410576527111}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:44:59,387] Trial 24 finished with value: 0.7345496156885698 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05833183408681043, 'learning_rate': 0.06952213514292352, 'depth': 7, 'boosting_type': 'Ordered', 'l2_leaf_reg': 3, 'min_data_in_leaf': 18, 'bootstrap_type': 'Bernoulli', 'subsample': 0.26772664891841597}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:45:11,793] Trial 25 finished with value: 0.737170603412468 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06366067466243315, 'learning_rate': 0.03994895546176739, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 31, 'bootstrap_type': 'Bernoulli', 'subsample': 0.40383925551527555}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:45:24,376] Trial 26 finished with value: 0.7103795272930887 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08740356912457643, 'learning_rate': 0.09127898109516382, 'depth': 11, 'boosting_type': 'Plain', 'l2_leaf_reg': 4, 'min_data_in_leaf': 49, 'bootstrap_type': 'Bernoulli', 'subsample': 0.2303322231656959}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:45:32,637] Trial 27 finished with value: 0.7449678822726071 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03932203494455939, 'learning_rate': 0.06090232217297224, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 8, 'bootstrap_type': 'Bernoulli', 'subsample': 0.815460928657831}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:45:40,230] Trial 28 finished with value: 0.6827581900993096 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.02380788198863979, 'learning_rate': 0.04565649405331782, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 76, 'bootstrap_type': 'MVS'}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:45:56,755] Trial 29 finished with value: 0.7419892153796461 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0683665436291135, 'learning_rate': 0.030791315004567794, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 32, 'bootstrap_type': 'Bernoulli', 'subsample': 0.46268182301276695}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:46:10,374] Trial 30 finished with value: 0.6991459135265626 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08623479445788707, 'learning_rate': 0.009723104046285146, 'depth': 7, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 44, 'bootstrap_type': 'Bernoulli', 'subsample': 0.16475543972515894}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:46:30,253] Trial 31 finished with value: 0.7535221141381478 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0733020316202129, 'learning_rate': 0.023423307991877505, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 55, 'bootstrap_type': 'Bernoulli', 'subsample': 0.5375135526233861}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:46:52,757] Trial 32 finished with value: 0.7653481886839781 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06595646446262231, 'learning_rate': 0.0694256939394313, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 45, 'bootstrap_type': 'Bernoulli', 'subsample': 0.710928010637218}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:47:03,974] Trial 33 finished with value: 0.7491969465285143 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04638291695001002, 'learning_rate': 0.06747152230706586, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 47, 'bootstrap_type': 'Bernoulli', 'subsample': 0.7036625571409986}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:47:16,611] Trial 34 finished with value: 0.7580601989042933 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.06542133822679479, 'learning_rate': 0.04065520753901452, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 57, 'bootstrap_type': 'Bernoulli', 'subsample': 0.6990600948624144}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:47:19,992] Trial 35 finished with value: 0.7597769467473179 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05184148643011558, 'learning_rate': 0.09290311351602239, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 6, 'min_data_in_leaf': 30, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9945925611140497}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:47:48,188] Trial 36 finished with value: 0.7608079055620365 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0897834839941523, 'learning_rate': 0.0711482350988919, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 76, 'bootstrap_type': 'Bernoulli', 'subsample': 0.784666151068095}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:48:53,291] Trial 37 finished with value: 0.761070214687718 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09151189670688215, 'learning_rate': 0.035256467281513645, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 74, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.2652509460219754}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:49:35,561] Trial 38 finished with value: 0.6755860354368096 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0775285945079524, 'learning_rate': 0.0010227390558702372, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 65, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.03144162762472558}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:49:50,690] Trial 39 finished with value: 0.685791661940047 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.0803582841509354, 'learning_rate': 0.016975106188968688, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 10, 'min_data_in_leaf': 99, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.565745250947902}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:49:56,820] Trial 40 finished with value: 0.6292864067310384 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.01417049960174799, 'learning_rate': 0.03145193234953419, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 71, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.398547993425989}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:50:22,541] Trial 41 finished with value: 0.723783142766289 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09058731130513548, 'learning_rate': 0.07632425930898337, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 89, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.473163093059438}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:50:58,533] Trial 42 finished with value: 0.7378464029094692 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08823427823475123, 'learning_rate': 0.09998978799209227, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 84, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.4778429403474886}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:51:05,108] Trial 43 finished with value: 0.6054094468904727 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.07618306253528659, 'learning_rate': 0.03971870870396502, 'depth': 1, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 62, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.33684070364246}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:51:34,739] Trial 44 finished with value: 0.7615847358118482 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09907935306650575, 'learning_rate': 0.04647958228228455, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 72, 'bootstrap_type': 'MVS'}. Best is trial 11 with value: 0.7718443735551433.
# [I 2024-02-12 10:53:02,733] Trial 45 finished with value: 0.7797841976999641 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09729979585604012, 'learning_rate': 0.027719959638573426, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 69, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# [I 2024-02-12 10:53:51,592] Trial 46 finished with value: 0.7592789486921712 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09929749791951825, 'learning_rate': 0.014009420236209321, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 70, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# [I 2024-02-12 10:54:02,230] Trial 47 finished with value: 0.7580806525870467 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.07075250149209389, 'learning_rate': 0.04792465245981369, 'depth': 12, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 8, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# [I 2024-02-12 10:54:15,347] Trial 48 finished with value: 0.7471156421731963 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08065109661327781, 'learning_rate': 0.027046844559488636, 'depth': 7, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 61, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# [I 2024-02-12 10:54:24,341] Trial 49 finished with value: 0.6982810774440077 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.034540642572791776, 'learning_rate': 0.018597549812900297, 'depth': 6, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 22, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# [I 2024-02-12 10:54:35,834] Trial 50 finished with value: 0.7572652968908009 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.05539716737070858, 'learning_rate': 0.04958722890295128, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 53, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# [I 2024-02-12 10:55:41,444] Trial 51 finished with value: 0.7742242208233925 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09170950219689716, 'learning_rate': 0.037595042584391385, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 71, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# [I 2024-02-12 10:57:07,274] Trial 52 finished with value: 0.7752595134023921 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09964544067093581, 'learning_rate': 0.04056633853910538, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 68, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# [I 2024-02-12 11:00:47,555] Trial 53 finished with value: 0.771646311922601 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09801623835572115, 'learning_rate': 0.057396766740177685, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 70, 'bootstrap_type': 'MVS'}. Best is trial 45 with value: 0.7797841976999641.
# Number of finished trials: 54
# Best trial:
#   Value: 0.7797841976999641
#   Params:
#     objective: CrossEntropy
#     colsample_bylevel: 0.09729979585604012
#     learning_rate: 0.027719959638573426
#     depth: 11
#     boosting_type: Ordered
#     l2_leaf_reg: 8
#     min_data_in_leaf: 69
#     bootstrap_type: MVS

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.09729979585604012, 'learning_rate': 0.027719959638573426, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 69, 'bootstrap_type': 'MVS'}
# Best score: 0.7797841976999641

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x13813f710>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.7569721115537849

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.76       123
#            1       0.77      0.75      0.76       128
#
#     accuracy                           0.76       251
#    macro avg       0.76      0.76      0.76       251
# weighted avg       0.76      0.76      0.76       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_in"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price  exp_call    exp_date  final_price  \
# Date
# 2018-02-05         0   265.0        8.22  4.942161  2018-02-28   271.649994
# 2018-02-22         0   270.0        4.26  6.397086  2018-03-14   275.299988
# 2018-03-08         0   274.0        2.85  5.917690  2018-03-29   263.149994
# 2018-03-09         0   279.0        2.47  5.505012  2018-03-29   263.149994
# 2018-04-03         1   260.5        5.09  5.247430  2018-04-23   266.570007
# ...              ...     ...         ...       ...         ...          ...
# 2022-10-25         0   385.0       10.50  9.062317  2022-11-14   395.119995
# 2022-11-01         1   385.0        9.48  8.719475  2022-11-21   394.589996
# 2022-11-02         1   375.0       10.19  8.901524  2022-11-23   402.420013
# 2022-12-01         0   407.0        7.97  9.399281  2022-12-23   382.910004
# 2022-12-19         0   380.0        7.22  7.839602  2023-01-06   388.079987
#
#                profit       bare  cum_profit    cum_bare
# Date
# 2018-02-05   0.000000  -1.570006    0.000000   -1.570006
# 2018-02-22   0.000000   1.039988    0.000000   -0.530018
# 2018-03-08   0.000000  -2.850000    0.000000   -3.380018
# 2018-03-09   0.000000  -2.470000    0.000000   -5.850018
# 2018-04-03   0.980007   0.980007    0.980007   -4.870011
# ...               ...        ...         ...         ...
# 2022-10-25   0.000000  -0.380005  516.059884  389.189830
# 2022-11-01   0.109996   0.109996  516.169880  389.299827
# 2022-11-02  17.230013  17.230013  533.399894  406.529840
# 2022-12-01   0.000000  -7.970000  533.399894  398.559840
# 2022-12-19   0.000000   0.859987  533.399894  399.419827
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions +data (Buy only in-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x137e03ed0>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.4262948207171315

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.23      0.36       177
#            1       0.33      0.89      0.48        74
#
#     accuracy                           0.43       251
#    macro avg       0.58      0.56      0.42       251
# weighted avg       0.69      0.43      0.40       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = new_df.iloc[-i, :].to_dict()
    quote_date = new_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price   exp_call    exp_date  final_price  \
# Date
# 2022-01-03         0   478.0        4.81  10.248337  2022-01-24   439.839996
# 2022-01-04         0   478.0        4.80   9.610177  2022-01-24   439.839996
# 2022-01-05         1   468.0        8.14  10.191128  2022-01-26   433.380005
# 2022-01-06         1   468.0        7.00   9.657596  2022-01-26   433.380005
# 2022-01-07         1   466.0        7.56   9.927762  2022-01-28   441.950012
# ...              ...     ...         ...        ...         ...          ...
# 2022-12-23         1   383.0        8.00   8.453400  2023-01-13   398.500000
# 2022-12-26         1   383.0        7.96   8.096501  2023-01-13   398.500000
# 2022-12-28         1   377.0        8.75   8.526141  2023-01-20   395.880005
# 2022-12-29         1   383.0        8.50   8.908718  2023-01-20   395.880005
# 2022-12-30         1   382.0        8.21   8.652675  2023-01-20   395.880005
#
#                profit       bare  cum_profit    cum_bare
# Date
# 2022-01-03   0.000000  -4.810000    0.000000   -4.810000
# 2022-01-04   0.000000  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000  -8.140000   -8.140000  -17.750000
# 2022-01-06  -7.000000  -7.000000  -15.140000  -24.750000
# 2022-01-07  -7.560000  -7.560000  -22.700000  -32.310000
# ...               ...        ...         ...         ...
# 2022-12-23   7.500000   7.500000 -381.129988 -525.980022
# 2022-12-26   7.540000   7.540000 -373.589988 -518.440022
# 2022-12-28  10.130005  10.130005 -363.459983 -508.310017
# 2022-12-29   4.380005   4.380005 -359.079978 -503.930012
# 2022-12-30   5.670005   5.670005 -353.409973 -498.260007
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions + data (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## Compare the two predictions

# %%
mask_in = (compare_df["bare_rf_pred_in"] - compare_df["mmar_rf_pred_in"]).astype(bool)
mask_out = (compare_df["bare_rf_pred_out"] - compare_df["mmar_rf_pred_out"]).astype(
    bool
)

# %%
compare_df[mask_in]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 0                  0                 1                1                 0
# 1                  0                 1                1                 0
# 3                  0                 1                1                 1
# 4                  0                 1                1                 1
# 7                  0                 1                1                 0
# ..               ...               ...              ...               ...
# 242                0                 1                1                 1
# 243                0                 1                1                 1
# 246                0                 1                1                 1
# 248                0                 1                1                 1
# 250                0                 1                1                 1
#
# [124 rows x 4 columns]

# %%
compare_df[mask_in].shape
# Out:
# (124, 4)

# %%
# Compare out of sample preds
compare_df[mask_out]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 0                  0                 1                1                 0
# 1                  0                 1                1                 0
# 7                  0                 1                1                 0
# 22                 0                 1                1                 0
# 27                 0                 1                0                 0
# 56                 0                 1                0                 0
# 59                 0                 1                0                 0
# 60                 0                 1                0                 0
# 61                 0                 1                0                 0
# 63                 0                 1                1                 0
# 64                 0                 1                1                 0
# 65                 0                 1                0                 0
# 137                0                 1                0                 0
# 140                0                 1                0                 0
# 141                0                 1                1                 0
# 142                0                 1                1                 0
# 143                0                 1                0                 0
# 144                0                 1                1                 0
# 145                0                 1                0                 0
# 146                0                 1                1                 0
# 148                0                 1                1                 0
# 149                0                 1                0                 0
# 150                0                 1                0                 0
# 151                0                 1                1                 0
# 152                0                 1                0                 0
# 153                0                 1                1                 0
# 154                0                 1                0                 0
# 155                0                 1                1                 0
# 156                0                 1                0                 0
# 157                0                 1                1                 0
# 158                0                 1                1                 0
# 159                0                 1                1                 0
# 160                0                 1                1                 0
# 161                0                 1                1                 0
# 162                0                 1                0                 0
# 163                0                 1                0                 0
# 164                0                 1                1                 0
# 165                0                 1                0                 0
# 167                0                 1                1                 0
# 168                0                 1                0                 0
# 170                0                 1                0                 0
# 171                0                 1                1                 0
# 174                0                 1                1                 0
# 175                0                 1                1                 0
# 176                0                 1                0                 0
# 177                0                 1                0                 0
# 232                0                 1                0                 0
# 236                0                 1                0                 0
# 240                0                 1                1                 0

# %%
compare_df[mask_out].shape
# Out:
# (49, 4)

# %%
compare_df.sum(axis=0)
# Out:
# bare_rf_pred_in       1
# bare_rf_pred_out    251
# mmar_rf_pred_in     125
# mmar_rf_pred_out    202
# dtype: int64
