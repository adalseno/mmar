# %% [markdown]
# ## Compare CatBoost in the case of binary class (Sell, Buy)

# %%
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    classification_report,
    confusion_matrix,
)
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.pipeline import Pipeline

# %%
spy = pd.read_csv("../data/raw/spy.csv", parse_dates=True, index_col=0)

# %%
target = pd.read_csv("../data/processed/target_df.csv", parse_dates=True, index_col=0)[
    "target"
]

# %%
ml_df = pd.read_csv("../data/processed/ml_df.csv", parse_dates=True, index_col=0)

# %%
wk_df = pd.read_csv("../data/processed/exp_price.csv", parse_dates=True, index_col=0)

# %%
interest_rate = wk_df["r"].values

# %% [markdown]
# ### Functions

# %%
def display_report(y_test: np.ndarray, predictions: np.ndarray) -> None:
    print(classification_report(y_test, predictions))
    cm = confusion_matrix(y_test, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.show()
    return

# %%
def plot_feature_imp(coefficients: np.ndarray[float], columns: list[str]) -> None:
    feature_importance = pd.DataFrame(
        {"Feature": columns, "Importance": np.abs(coefficients)}
    )
    feature_importance = feature_importance.sort_values("Importance", ascending=True)
    feature_importance.plot(x="Feature", y="Importance", kind="barh", figsize=(10, 6))
    plt.show()
    return

# %% [markdown]
# ## Baseline CatBoost Classifier without new data + r

# %%
orig_df = ml_df[
    [
        "UNDERLYING_LAST",
        "STRIKE",
        "C_LAST",
        "C_BID",
        "C_ASK",
        "C_IV",
        "C_VOLUME",
        "diff_date",
    ]
].copy()

# %%
orig_df["r"] = interest_rate

# %% [markdown]
# ### In sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
# Adapted from https://github.com/optuna/optuna-examples/blob/main/catboost/catboost_pruning.py
def objective(trial: optuna.Trial) -> float:
    param = {
        "objective": trial.suggest_categorical(
            "objective", ["Logloss", "CrossEntropy"]
        ),
        "colsample_bylevel": trial.suggest_float(
            "colsample_bylevel", 0.01, 0.1, log=True
        ),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical(
            "boosting_type", ["Ordered", "Plain"]
        ),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 10),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    model = Pipeline(
        [
            ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
            (
                "rf",
                CatBoostClassifier(
                    **param, silent=True, early_stopping_rounds=50, random_state=1968
                ),
            ),
        ]
    )

    cv = StratifiedKFold(n_splits=4, shuffle=True, random_state=1968)

    return cross_val_score(
        model, X_train, y_train, cv=cv, scoring="f1_macro", n_jobs=1
    ).mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 07:40:00,324] A new study created in memory with name: no-name-3d3686e5-a108-4c95-a66a-c38066df326b
# [I 2024-02-12 07:40:08,848] Trial 0 finished with value: 0.47374843291676816 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.07257095055769096, 'learning_rate': 0.006596103101850734, 'depth': 1, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 87, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.977083690449643}. Best is trial 0 with value: 0.47374843291676816.
# [I 2024-02-12 07:40:16,040] Trial 1 finished with value: 0.6464875168705612 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.058751510355589356, 'learning_rate': 0.06857172196700609, 'depth': 6, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 60, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.304496849294543}. Best is trial 1 with value: 0.6464875168705612.
# [I 2024-02-12 07:40:23,374] Trial 2 finished with value: 0.583963759403866 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.04248415921486511, 'learning_rate': 0.023245045161459938, 'depth': 4, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 65, 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.6464875168705612.
# [I 2024-02-12 07:40:30,861] Trial 3 finished with value: 0.4189264239563364 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.059217492703094045, 'learning_rate': 0.0013837936820689921, 'depth': 3, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 56, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.1337235520798856}. Best is trial 1 with value: 0.6464875168705612.
# [I 2024-02-12 07:40:32,449] Trial 4 finished with value: 0.4045480815047448 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.
 'bootstrap_type': 'MVS'}. Best is trial 142 with value: 0.7153839395327881.
# [I 2024-02-12 07:46:58,538] Trial 146 finished with value: 0.6882501294001594 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08478967307861147, 'learning_rate': 0.09984953314365605, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 52, 'bootstrap_type': 'MVS'}. Best is trial 142 with value: 0.7153839395327881.
# [I 2024-02-12 07:47:00,695] Trial 147 finished with value: 0.6827080271400964 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09025654147167399, 'learning_rate': 0.025599407616260263, 'depth': 6, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 89, 'bootstrap_type': 'MVS'}. Best is trial 142 with value: 0.7153839395327881.
# [I 2024-02-12 07:47:07,111] Trial 148 finished with value: 0.5875134491374238 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.013422329600652226, 'learning_rate': 0.08495874460079629, 'depth': 5, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 40, 'bootstrap_type': 'MVS'}. Best is trial 142 with value: 0.7153839395327881.
# [I 2024-02-12 07:47:09,274] Trial 149 finished with value: 0.6253131974935598 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0998813180663404, 'learning_rate': 0.05826097743748926, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 8, 'min_data_in_leaf': 86, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.837389523496048}. Best is trial 142 with value: 0.7153839395327881.
# Number of finished trials: 150
# Best trial:
#   Value: 0.7153839395327881
#   Params:
#     objective: Logloss
#     colsample_bylevel: 0.09574236623731068
#     learning_rate: 0.09218844529419122
#     depth: 5
#     boosting_type: Plain
#     l2_leaf_reg: 9
#     min_data_in_leaf: 43
#     bootstrap_type: MVS

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09574236623731068, 'learning_rate': 0.09218844529419122, 'depth': 5, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 43, 'bootstrap_type': 'MVS'}
# Best score: 0.7153839395327881

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x12f820950>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6653386454183267

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.69      0.67       123
#            1       0.68      0.64      0.66       128
#
#     accuracy                           0.67       251
#    macro avg       0.67      0.67      0.67       251
# weighted avg       0.67      0.67      0.67       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df = pd.DataFrame(predictions, columns=["bare_rf_pred_in"])

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price     profit  \
# Date
# 2018-02-05         0   265.0        8.22  2018-02-28   271.649994   0.000000
# 2018-02-22         0   270.0        4.26  2018-03-14   275.299988   0.000000
# 2018-03-08         0   274.0        2.85  2018-03-29   263.149994   0.000000
# 2018-03-09         0   279.0        2.47  2018-03-29   263.149994   0.000000
# 2018-04-03         1   260.5        5.09  2018-04-23   266.570007   0.980007
# ...              ...     ...         ...         ...          ...        ...
# 2022-10-25         0   385.0       10.50  2022-11-14   395.119995   0.000000
# 2022-11-01         0   385.0        9.48  2022-11-21   394.589996   0.000000
# 2022-11-02         1   375.0       10.19  2022-11-23   402.420013  17.230013
# 2022-12-01         0   407.0        7.97  2022-12-23   382.910004   0.000000
# 2022-12-19         0   380.0        7.22  2023-01-06   388.079987   0.000000
#
#                  bare  cum_profit    cum_bare
# Date
# 2018-02-05  -1.570006    0.000000   -1.570006
# 2018-02-22   1.039988    0.000000   -0.530018
# 2018-03-08  -2.850000    0.000000   -3.380018
# 2018-03-09  -2.470000    0.000000   -5.850018
# 2018-04-03   0.980007    0.980007   -4.870011
# ...               ...         ...         ...
# 2022-10-25  -0.380005  363.229923  389.189830
# 2022-11-01   0.109996  363.229923  389.299827
# 2022-11-02  17.230013  380.459937  406.529840
# 2022-12-01  -7.970000  380.459937  398.559840
# 2022-12-19   0.859987  380.459937  399.419827
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only in sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    orig_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x12ffbdd50>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.6095617529880478

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.83      0.75       177
#            1       0.17      0.08      0.11        74
#
#     accuracy                           0.61       251
#    macro avg       0.43      0.46      0.43       251
# weighted avg       0.53      0.61      0.56       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = orig_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["bare_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = orig_df.iloc[-i, :].to_dict()
    quote_date = orig_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price    exp_date  final_price  profit  \
# Date
# 2022-01-03         0   478.0        4.81  2022-01-24   439.839996     0.0
# 2022-01-04         0   478.0        4.80  2022-01-24   439.839996     0.0
# 2022-01-05         0   468.0        8.14  2022-01-26   433.380005     0.0
# 2022-01-06         0   468.0        7.00  2022-01-26   433.380005     0.0
# 2022-01-07         0   466.0        7.56  2022-01-28   441.950012     0.0
# ...              ...     ...         ...         ...          ...     ...
# 2022-12-23         0   383.0        8.00  2023-01-13   398.500000     0.0
# 2022-12-26         0   383.0        7.96  2023-01-13   398.500000     0.0
# 2022-12-28         0   377.0        8.75  2023-01-20   395.880005     0.0
# 2022-12-29         0   383.0        8.50  2023-01-20   395.880005     0.0
# 2022-12-30         0   382.0        8.21  2023-01-20   395.880005     0.0
#
#                  bare  cum_profit    cum_bare
# Date
# 2022-01-03  -4.810000    0.000000   -4.810000
# 2022-01-04  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000    0.000000  -17.750000
# 2022-01-06  -7.000000    0.000000  -24.750000
# 2022-01-07  -7.560000    0.000000  -32.310000
# ...               ...         ...         ...
# 2022-12-23   7.500000 -206.130005 -525.980022
# 2022-12-26   7.540000 -206.130005 -518.440022
# 2022-12-28  10.130005 -206.130005 -508.310017
# 2022-12-29   4.380005 -206.130005 -503.930012
# 2022-12-30   5.670005 -206.130005 -498.260007
#
# [251 rows x 9 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## CatBoost with data from MC simulation and additional features

# %%
new_df = pd.concat(
    (
        ml_df[
            [
                "UNDERLYING_LAST",
                "STRIKE",
                "C_LAST",
                "C_BID",
                "C_ASK",
                "C_IV",
                "C_VOLUME",
                "diff",
            ]
        ],
        wk_df.drop(["last_quote", "strike"], axis=1),
    ),
    axis=1,
)

# %%
# Add some features
new_df["iqr"] = new_df["exp_price_q3"] - new_df["exp_price_q1"]
new_df["diff_call"] = new_df["exp_call_price"] - new_df["C_LAST"]
new_df["exp_price_var"] = np.power(new_df["exp_price_std"], 2)
new_df["exp_profit"] = new_df["exp_price"] - (new_df["STRIKE"] + new_df["C_LAST"])

# %% [markdown]
# ### In-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df, target.values.flatten(), test_size=0.2, random_state=1968, shuffle=True
)

# %% [markdown]
# ### Hyper-parameters tuning using Optuna

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150, timeout=900)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2024-02-12 07:47:14,681] A new study created in memory with name: no-name-4f695dff-cbe7-4469-85fe-508fde5deec0
# [I 2024-02-12 07:47:23,574] Trial 0 finished with value: 0.5993751669618633 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.041916947165483116, 'learning_rate': 0.00466912828229636, 'depth': 5, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 28, 'bootstrap_type': 'Bernoulli', 'subsample': 0.22248637936085433}. Best is trial 0 with value: 0.5993751669618633.
# [I 2024-02-12 07:47:25,945] Trial 1 finished with value: 0.6555359515557428 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.039717823551193035, 'learning_rate': 0.006767720065119068, 'depth': 7, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 88, 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.6555359515557428.
# [I 2024-02-12 07:47:33,847] Trial 2 finished with value: 0.6037891218447102 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03517119365598216, 'learning_rate': 0.006715829468559231, 'depth': 5, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 17, 'bootstrap_type': 'Bernoulli', 'subsample': 0.1037362074160213}. Best is trial 1 with value: 0.6555359515557428.
# [I 2024-02-12 07:47:40,085] Trial 3 finished with value: 0.6352622682642513 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.011646142628739318, 'learning_rate': 0.04501734133875939, 'depth': 7, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 24, 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.6555359515557428.
# [I 2024-02-12 07:47:42,029] Trial 4 finished with value: 0.4620641853386311 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.023888580665865168, 'learning_rate': 0.0011216097941384956, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 7, 'min_data_in_leaf': 86, 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.6555359515557428.
# [I 2024-02-12 07:47:49,172] Trial 5 finished with value: 0.7087963636287435 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03072712996164329, 'learning_rate': 0.045621416228275855, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 37, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.03919629371848643}. Best is trial 5 with value: 0.7087963636287435.
# [I 2024-02-12 07:47:57,420] Trial 6 finished with value: 0.533391504043666 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0355295051149951, 'learning_rate': 0.002253804898271933, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 95, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.4527599927138555}. Best is trial 5 with value: 0.7087963636287435.
# [I 2024-02-12 07:48:03,837] Trial 7 finished with value: 0.5646093762614395 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.012640021947924988, 'learning_rate': 0.01434362631129689, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 2, 'min_data_in_leaf': 13, 'bootstrap_type': 'MVS'}. Best is trial 5 with value: 0.7087963636287435.
# [I 2024-02-12 07:48:05,722] Trial 8 finished with value: 0.6084711110887392 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.033059266897409054, 'learning_rate': 0.017042266214973362, 'depth': 2, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 60, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.15439751478585}. Best is trial 5 with value: 0.7087963636287435.
# [I 2024-02-12 07:48:08,462] Trial 9 finished with value: 0.6826421930239503 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09151005482430567, 'learning_rate': 0.02122158969196919, 'depth': 4, 'boosting_type': 'Plain', 'l2_leaf_reg': 2, 'min_data_in_leaf': 92, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.18502424778433}. Best is trial 5 with value: 0.7087963636287435.
# [I 2024-02-12 07:49:03,627] Trial 10 finished with value: 0.7546910559990944 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06526617043890084, 'learning_rate': 0.09414507000574712, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 51, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.5241007641906261}. Best is trial 10 with value: 0.7546910559990944.
# [I 2024-02-12 07:50:54,159] Trial 11 finished with value: 0.7585004892111628 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07928709278138495, 'learning_rate': 0.0895035118509726, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 45, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.29693410754600186}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:53:45,720] Trial 12 finished with value: 0.7486122578441914 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09108504521127994, 'learning_rate': 0.09511318420089539, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 59, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.071832171019826}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:54:26,757] Trial 13 finished with value: 0.7503525322024084 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06148656760285714, 'learning_rate': 0.09077270920390201, 'depth': 12, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 50, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.44058861862628457}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:54:39,208] Trial 14 finished with value: 0.7159307332817536 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05917750803603466, 'learning_rate': 0.04257977565394031, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 5, 'min_data_in_leaf': 71, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.470217341906505}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:54:58,288] Trial 15 finished with value: 0.685084833836451 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.06133787264273271, 'learning_rate': 0.03015973834070577, 'depth': 10, 'boosting_type': 'Ordered', 'l2_leaf_reg': 10, 'min_data_in_leaf': 1, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.059332555744195}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:55:33,555] Trial 16 finished with value: 0.7506746992994606 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07127861071393476, 'learning_rate': 0.06762685851367481, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 44, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9848234503996628}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:55:40,063] Trial 17 finished with value: 0.6368271526712012 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.022706835303321328, 'learning_rate': 0.06135840842409619, 'depth': 9, 'boosting_type': 'Ordered', 'l2_leaf_reg': 9, 'min_data_in_leaf': 69, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.068430848046749}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:55:42,203] Trial 18 finished with value: 0.6601874965003087 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.048992976746585766, 'learning_rate': 0.026128512842668167, 'depth': 2, 'boosting_type': 'Plain', 'l2_leaf_reg': 10, 'min_data_in_leaf': 38, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.7630953565668106}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:55:56,572] Trial 19 finished with value: 0.7327018687412877 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07795218734522742, 'learning_rate': 0.012798515127187365, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 4, 'min_data_in_leaf': 73, 'bootstrap_type': 'Bernoulli', 'subsample': 0.9750483753559459}. Best is trial 11 with value: 0.7585004892111628.
# [I 2024-02-12 07:57:26,584] Trial 20 finished with value: 0.7595545621921284 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09936996230348916, 'learning_rate': 0.09999504943839765, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 61, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.1284655913423913}. Best is trial 20 with value: 0.7595545621921284.
# [I 2024-02-12 07:58:46,790] Trial 21 finished with value: 0.7648067919239434 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09870625179790898, 'learning_rate': 0.06762709799342605, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 58, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.8473085234705752}. Best is trial 21 with value: 0.7648067919239434.
# [I 2024-02-12 08:00:00,437] Trial 22 finished with value: 0.7406395782539392 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09601205680215559, 'learning_rate': 0.05930061657062614, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 59, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.7061180826815612}. Best is trial 21 with value: 0.7648067919239434.
# [I 2024-02-12 08:00:41,719] Trial 23 finished with value: 0.7277780741340165 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.07645539704746929, 'learning_rate': 0.03208199257400494, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 7, 'min_data_in_leaf': 79, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.3577714603265454}. Best is trial 21 with value: 0.7648067919239434.
# [I 2024-02-12 08:01:01,890] Trial 24 finished with value: 0.7579532726218994 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09956288858129302, 'learning_rate': 0.06724890651002749, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 52, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.2037334465435545}. Best is trial 21 with value: 0.7648067919239434.
# [I 2024-02-12 08:01:16,015] Trial 25 finished with value: 0.7165444701468 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.050610778036951104, 'learning_rate': 0.04285555797271139, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 65, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.847181363848608}. Best is trial 21 with value: 0.7648067919239434.
# [I 2024-02-12 08:01:22,636] Trial 26 finished with value: 0.6918809419450872 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.07675841585894215, 'learning_rate': 0.07383131392433835, 'depth': 10, 'boosting_type': 'Plain', 'l2_leaf_reg': 9, 'min_data_in_leaf': 37, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.616422185973837}. Best is trial 21 with value: 0.7648067919239434.
# [I 2024-02-12 08:01:32,338] Trial 27 finished with value: 0.7436288007775409 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.053414876889603405, 'learning_rate': 0.0339882138628494, 'depth': 8, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 45, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.008017917919837081}. Best is trial 21 with value: 0.7648067919239434.
# [I 2024-02-12 08:02:24,646] Trial 28 finished with value: 0.7626252756558171 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0812135845049604, 'learning_rate': 0.09621269477520718, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 6, 'min_data_in_leaf': 78, 'bootstrap_type': 'MVS'}. Best is trial 21 with value: 0.7648067919239434.
# Number of finished trials: 29
# Best trial:
#   Value: 0.7648067919239434
#   Params:
#     objective: Logloss
#     colsample_bylevel: 0.09870625179790898
#     learning_rate: 0.06762709799342605
#     depth: 11
#     boosting_type: Ordered
#     l2_leaf_reg: 8
#     min_data_in_leaf: 58
#     bootstrap_type: Bayesian
#     bagging_temperature: 0.8473085234705752

# %%
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# Best hyperparameters: {'objective': 'Logloss', 'colsample_bylevel': 0.09870625179790898, 'learning_rate': 0.06762709799342605, 'depth': 11, 'boosting_type': 'Ordered', 'l2_leaf_reg': 8, 'min_data_in_leaf': 58, 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.8473085234705752}
# Best score: 0.7648067919239434

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x10ba306d0>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.7729083665338645

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77       123
#            1       0.79      0.76      0.77       128
#
#     accuracy                           0.77       251
#    macro avg       0.77      0.77      0.77       251
# weighted avg       0.77      0.77      0.77       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_in"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
prev_price = 0.0
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = X_test.iloc[-i, :].to_dict()
    quote_date = X_test.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    # Needed since a day in YF is missing
    try:
        final_price = spy.loc[exp_date, "Close"]
    except KeyError:
        final_price = prev_price
    prev_price = final_price
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

strategy_df = strategy_df.sort_index()

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price  exp_call    exp_date  final_price  \
# Date
# 2018-02-05         0   265.0        8.22  4.942161  2018-02-28   271.649994
# 2018-02-22         0   270.0        4.26  6.397086  2018-03-14   275.299988
# 2018-03-08         0   274.0        2.85  5.917690  2018-03-29   263.149994
# 2018-03-09         0   279.0        2.47  5.505012  2018-03-29   263.149994
# 2018-04-03         1   260.5        5.09  5.247430  2018-04-23   266.570007
# ...              ...     ...         ...       ...         ...          ...
# 2022-10-25         0   385.0       10.50  9.062317  2022-11-14   395.119995
# 2022-11-01         1   385.0        9.48  8.719475  2022-11-21   394.589996
# 2022-11-02         1   375.0       10.19  8.901524  2022-11-23   402.420013
# 2022-12-01         0   407.0        7.97  9.399281  2022-12-23   382.910004
# 2022-12-19         1   380.0        7.22  7.839602  2023-01-06   388.079987
#
#                profit       bare  cum_profit    cum_bare
# Date
# 2018-02-05   0.000000  -1.570006    0.000000   -1.570006
# 2018-02-22   0.000000   1.039988    0.000000   -0.530018
# 2018-03-08   0.000000  -2.850000    0.000000   -3.380018
# 2018-03-09   0.000000  -2.470000    0.000000   -5.850018
# 2018-04-03   0.980007   0.980007    0.980007   -4.870011
# ...               ...        ...         ...         ...
# 2022-10-25   0.000000  -0.380005  554.619839  389.189830
# 2022-11-01   0.109996   0.109996  554.729835  389.299827
# 2022-11-02  17.230013  17.230013  571.959849  406.529840
# 2022-12-01   0.000000  -7.970000  571.959849  398.559840
# 2022-12-19   0.859987   0.859987  572.819835  399.419827
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions +data (Buy only in-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ### Out-of-sample predictions

# %%
X_train, X_test, y_train, y_test = train_test_split(
    new_df.values,
    target.values.flatten(),
    test_size=0.2,
    random_state=1968,
    shuffle=False,
)

# %%
pipe = Pipeline(
    [
        ("imputer", SimpleImputer(strategy="constant", fill_value=0.0)),
        ("rf", CatBoostClassifier(**study.best_params, silent=True)),
    ]
)

# %%
# Fit the tuned model
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(fill_value=0.0, strategy='constant')),
#                 ('rf',
#                  <catboost.core.CatBoostClassifier object at 0x13015c5d0>)])

# %%
predictions = pipe.predict(X_test)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.4063745019920319

# %%
display_report(y_test, predictions)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.19      0.31       177
#            1       0.32      0.92      0.48        74
#
#     accuracy                           0.41       251
#    macro avg       0.59      0.56      0.40       251
# weighted avg       0.69      0.41      0.36       251

# %%
coefficients = pipe.named_steps["rf"].feature_importances_
columns = new_df.columns
plot_feature_imp(coefficients, columns)

# %%
compare_df["mmar_rf_pred_out"] = predictions

# %% [markdown]
# ### Backtesting

# %%
strategy = []
date_idx = []
for x, i in enumerate(range(len(predictions), 0, -1)):
    row = new_df.iloc[-i, :].to_dict()
    quote_date = new_df.index[-i]
    exp_date = pd.to_datetime(ml_df.loc[quote_date, "EXPIRE_DATE"])
    final_price = spy.loc[exp_date, "Close"]
    call_price = row["C_LAST"]
    strike = row["STRIKE"]
    if predictions[x]:  # buy
        if final_price > strike:
            profit = final_price - (strike + call_price)
        else:
            profit = -call_price
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": profit,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    else:
        res = {
            "strategy": predictions[x],
            "strike": strike,
            "call_price": row["C_LAST"],
            "exp_call": row["exp_call_price"],
            "exp_date": ml_df.loc[quote_date, "EXPIRE_DATE"],
            "final_price": final_price,
            "profit": 0.0,
            "bare": max(final_price - (strike + call_price), -call_price),
        }
    strategy.append(res)
    date_idx.append(quote_date)

# %%
strategy_df = pd.DataFrame(strategy, pd.Index(name="Date", data=date_idx))

# %%
strategy_df["cum_profit"] = np.cumsum(strategy_df.profit.values)
strategy_df["cum_bare"] = np.cumsum(strategy_df.bare.values)

# %%
strategy_df
# Out:
#             strategy  strike  call_price   exp_call    exp_date  final_price  \
# Date
# 2022-01-03         0   478.0        4.81  10.248337  2022-01-24   439.839996
# 2022-01-04         0   478.0        4.80   9.610177  2022-01-24   439.839996
# 2022-01-05         1   468.0        8.14  10.191128  2022-01-26   433.380005
# 2022-01-06         1   468.0        7.00   9.657596  2022-01-26   433.380005
# 2022-01-07         1   466.0        7.56   9.927762  2022-01-28   441.950012
# ...              ...     ...         ...        ...         ...          ...
# 2022-12-23         1   383.0        8.00   8.453400  2023-01-13   398.500000
# 2022-12-26         1   383.0        7.96   8.096501  2023-01-13   398.500000
# 2022-12-28         1   377.0        8.75   8.526141  2023-01-20   395.880005
# 2022-12-29         1   383.0        8.50   8.908718  2023-01-20   395.880005
# 2022-12-30         1   382.0        8.21   8.652675  2023-01-20   395.880005
#
#                profit       bare  cum_profit    cum_bare
# Date
# 2022-01-03   0.000000  -4.810000    0.000000   -4.810000
# 2022-01-04   0.000000  -4.800000    0.000000   -9.610000
# 2022-01-05  -8.140000  -8.140000   -8.140000  -17.750000
# 2022-01-06  -7.000000  -7.000000  -15.140000  -24.750000
# 2022-01-07  -7.560000  -7.560000  -22.700000  -32.310000
# ...               ...        ...         ...         ...
# 2022-12-23   7.500000   7.500000 -359.909993 -525.980022
# 2022-12-26   7.540000   7.540000 -352.369993 -518.440022
# 2022-12-28  10.130005  10.130005 -342.239988 -508.310017
# 2022-12-29   4.380005   4.380005 -337.859983 -503.930012
# 2022-12-30   5.670005   5.670005 -332.189978 -498.260007
#
# [251 rows x 10 columns]

# %%
strategy_df[["cum_profit", "cum_bare"]].plot(
    figsize=(12, 6),
    ylabel="Cumulated profit",
    title="Example strategy based on CatBoost predictions + data (Buy only out-of-sample)",
)
ax = plt.gca()
text = f"Strategy cumulated profit: {strategy_df['cum_profit'].iloc[-1]:.2f} in {strategy_df['strategy'].sum()} tradings"
plt.text(0.3, 0.85, text, transform=ax.transAxes)
plt.legend()
plt.show()

# %% [markdown]
# ## Compare the two predictions

# %%
mask_in = (compare_df["bare_rf_pred_in"] - compare_df["mmar_rf_pred_in"]).astype(bool)
mask_out = (compare_df["bare_rf_pred_out"] - compare_df["mmar_rf_pred_out"]).astype(
    bool
)

# %%
compare_df[mask_in]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 0                  1                 0                0                 0
# 16                 0                 1                1                 1
# 21                 1                 1                0                 0
# 36                 0                 1                1                 1
# 39                 0                 1                1                 1
# 40                 0                 1                1                 1
# 47                 0                 0                1                 1
# 50                 0                 0                1                 1
# 51                 1                 0                0                 1
# 55                 0                 0                1                 1
# 69                 1                 0                0                 1
# 71                 0                 0                1                 1
# 76                 1                 0                0                 1
# 89                 0                 0                1                 1
# 97                 0                 0                1                 1
# 99                 0                 0                1                 1
# 103                0                 0                1                 1
# 110                1                 0                0                 1
# 111                1                 0                0                 1
# 112                1                 0                0                 1
# 114                0                 0                1                 1
# 117                1                 0                0                 1
# 119                0                 0                1                 1
# 120                0                 0                1                 1
# 122                0                 0                1                 1
# 127                0                 0                1                 1
# 131                0                 0                1                 1
# 133                1                 0                0                 1
# 141                0                 0                1                 1
# 145                1                 0                0                 0
# 151                0                 0                1                 1
# 156                1                 0                0                 0
# 158                0                 0                1                 1
# 162                1                 0                0                 0
# 163                1                 0                0                 0
# 171                0                 0                1                 1
# 173                0                 0                1                 1
# 174                0                 0                1                 0
# 187                1                 0                0                 1
# 188                0                 0                1                 1
# 191                0                 0                1                 1
# 193                1                 0                0                 1
# 194                1                 0                0                 1
# 195                1                 0                0                 1
# 202                1                 0                0                 1
# 212                1                 0                0                 1
# 216                0                 0                1                 1
# 225                1                 0                0                 1
# 232                1                 0                0                 1
# 237                1                 0                0                 1
# 238                1                 0                0                 1
# 246                0                 0                1                 1
# 247                1                 0                0                 1

# %%
compare_df[mask_in].shape
# Out:
# (53, 4)

# %%
# Compare out of sample preds
compare_df[mask_out]
# Out:
#      bare_rf_pred_in  bare_rf_pred_out  mmar_rf_pred_in  mmar_rf_pred_out
# 2                  0                 0                0                 1
# 3                  1                 0                1                 1
# 4                  1                 0                1                 1
# 5                  0                 0                0                 1
# 8                  0                 0                0                 1
# ..               ...               ...              ...               ...
# 246                0                 0                1                 1
# 247                1                 0                0                 1
# 248                1                 0                1                 1
# 249                0                 0                0                 1
# 250                1                 0                1                 1
#
# [181 rows x 4 columns]

# %%
compare_df[mask_out].shape
# Out:
# (181, 4)

# %%
compare_df.sum(axis=0)
# Out:
# bare_rf_pred_in     120
# bare_rf_pred_out     36
# mmar_rf_pred_in     123
# mmar_rf_pred_out    211
# dtype: int64
